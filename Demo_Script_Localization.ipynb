# %%
#import the required libraries
import os
import docx
import openai
import nltk
from docx import Document
from docx.shared import Inches
import base64
from io import BytesIO


# Import LangChain library
import langchain
# Import Streamlit 
import streamlit as st

# %%
os.environ['OPENAI_API_KEY'] = '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'
OPENAI_API_KEY="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"
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')
def get_completion(prompt, model="gpt-3.5-turbo"): 
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
#creating a path to get docx file (demo script)
path = os.path.join(os.getcwd(), 'C:/projects/Emplay assessment/demo-script-employee-central-overview.docx')
#opening the docx file
doc = docx.Document(path)
#getting the text from the docx file
text = []
for para in doc.paragraphs:
    text.append(para.text)
    
#printing the text from the docx file
print(text)
# Out:
# ['Demo Script:', 'Employee Central Overview', '', '', 'Employee Central (EC) Overview', 'for Internal SAP and Partner Use Only', 'Page 1 of 27', '', '', 'Objectives:', 'To enable/familiarize yourself with demoing EC.', '', 'To use as a starting point for planning your EC demo.', '', 'Tips and Tricks:', 'Simplicity is good. Consider simplifying your People Profile and manager self-service role so that everything that isn’t relevant for your story is removed.', '', 'Reflect your prospect’s HR delivery model. If they work with a shared service center and HR business partners, you may want to reflect it in your workflow definitions.', '', 'Preparation:', 'Workflows - Correct the transfer without pay change workflow to remove the manager role so they are not the approver for the transaction (This is fixed in the 2018 Summer Release).', '', 'o HOW:', 'Log in as sfadmin', 'Go to Admin Tools -> Manage Organization, Pay and Job Structures', 'In the first drop down, select Workflow', 'In the s
# ...

# %%
from docx import Document

def extract_text_from_docx(docx_path):
    doc = Document(docx_path)
    full_text = []
    for para in doc.paragraphs:
        full_text.append(para.text)
    return '\n'.join(full_text)

docx_path = 'C:/projects/Emplay assessment/demo-script-employee-central-overview.docx'
text = extract_text_from_docx(docx_path)
print(text)
# Out:
# Demo Script:
# Employee Central Overview
#
#
# Employee Central (EC) Overview
# for Internal SAP and Partner Use Only
# Page 1 of 27
#
#
# Objectives:
# To enable/familiarize yourself with demoing EC.
#
# To use as a starting point for planning your EC demo.
#
# Tips and Tricks:
# Simplicity is good. Consider simplifying your People Profile and manager self-service role so that everything that isn’t relevant for your story is removed.
#
# Reflect your prospect’s HR delivery model. If they work with a shared service center and HR business partners, you may want to reflect it in your workflow definitions.
#
# Preparation:
# Workflows - Correct the transfer without pay change workflow to remove the manager role so they are not the approver for the transaction (This is fixed in the 2018 Summer Release).
#
# o HOW:
# Log in as sfadmin
# Go to Admin Tools -> Manage Organization, Pay and Job Structures
# In the first drop down, select Workflow
# In the second drop down, select XFER
# ...

# %%
#Read the input document: Use a library like python-docx to read the contents of the input demo script document.

doc = docx.Document('C:/projects/Emplay assessment/demo-script-employee-central-overview.docx') 
      
for para in doc.paragraphs:
    print(para.text)
    print(para.style)
    print(para.runs)
# Out:
# Demo Script:
# _ParagraphStyle('normal') id: 2338407694688
# ...
# Employee Central Overview
# _ParagraphStyle('normal') id: 2338407694688
# ...
#
# _ParagraphStyle('normal') id: 2338407694688
# ...
#
# _ParagraphStyle('normal') id: 2338407694688
# ...
# Employee Central (EC) Overview
# _ParagraphStyle('normal') id: 2338407694688
# ...
# for Internal SAP and Partner Use Only
# _ParagraphStyle('normal') id: 2338407694688
# ...
# Page 1 of 27
# _ParagraphStyle('normal') id: 2338407694688
# ...
#
# _ParagraphStyle('normal') id: 2338407694688
# ...
#
# _ParagraphStyle('normal') id: 2338407694688
# ...
# Objectives:
# _ParagraphStyle('normal') id: 2338407694688
# ...
# To enable/familiarize yourself with demoing EC.
# _ParagraphStyle('normal') id: 2338407694688
# ...
#
# _ParagraphStyle('normal') id: 2338407694688
# ...
# To use as a starting point for planning your EC demo.
# _ParagraphStyle('normal') id: 2338407694688
# ...
#
# _ParagraphStyle('normal') id: 2338407694688
# ...
# Tips and Tricks:
# _ParagraphStyle('normal') id: 2338407694688
# ...

# %%
#Tokenize the text: Use a natural language processing library like nltk or spaCy to tokenize the text into sentences and words.

import nltk
#Tokenize the text: Use nltk to tokenize the text into sentences and words.
from nltk.tokenize import sent_tokenize, word_tokenize
text = extract_text_from_docx(docx_path)
print(sent_tokenize(text))
print(word_tokenize(text))
# Out:
# ['Demo Script:\nEmployee Central Overview\n\n\nEmployee Central (EC) Overview\nfor Internal SAP and Partner Use Only\nPage 1 of 27\n\n\nObjectives:\nTo enable/familiarize yourself with demoing EC.', 'To use as a starting point for planning your EC demo.', 'Tips and Tricks:\nSimplicity is good.', 'Consider simplifying your People Profile and manager self-service role so that everything that isn’t relevant for your story is removed.', 'Reflect your prospect’s HR delivery model.', 'If they work with a shared service center and HR business partners, you may want to reflect it in your workflow definitions.', 'Preparation:\nWorkflows - Correct the transfer without pay change workflow to remove the manager role so they are not the approver for the transaction (This is fixed in the 2018 Summer Release).', 'o HOW:\nLog in as sfadmin\nGo to Admin Tools -> Manage Organization, Pay and Job Structures\nIn the first drop down, select Workflow\nIn the second drop down, select XFER\nIn the upper rig
# ...

# %%
#Identify names: Use named entity recognition to identify names in the text that need to be localized.
import spacy

def identify_names(text):
    nlp = spacy.load('en_core_web_sm')
    doc = nlp(text)
    names = []
    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            names.append(ent.text)
    return names

docx_path = 'C:/projects/Emplay assessment/demo-script-employee-central-overview.docx'
text = extract_text_from_docx(docx_path)
names = identify_names(text)
print(names)
# Out:
# ['Admin Tools ->', 'Job Structures', 'Login', 'Administer Time', 'Vanessa Wagner', 'Freda Hoch', 'Amelie Verrier', 'Coline Gage', 'Sandra Gray', 'Liam Seaward', 'Mya Cooper', 'Gordon Elliston', 'Apps', 'Vanessa Wagner', 'App', 'App', 'Freda', 'Tessa Walker', 'Show Workflow', 'Twalker', 'Vanessa', 'Freda', 'Click Link', 'Click Question', 'Tessa', 'Letś', 'Brunnert', 'Ralph Brunnert', 'Freda', 'Beside', 'Click', 'Click Take', 'Action Search', 'Hire Ingrid', 'Localization Tile', 'Letś', 'Contingent Labour']

# %%
from docx import Document

def extract_text_from_docx(docx_path):
    doc = Document(docx_path)
    full_text = []
    for para in doc.paragraphs:
        full_text.append(para.text)
    return '\n'.join(full_text)

docx_path = 'C:/projects/Emplay assessment/Localized-demo-script-employee-central-overview--spanish.docx'
text = extract_text_from_docx(docx_path)
print(text)
# Out:
# Guión de demostración:
# Descripción general de la central de empleados
#
#
# Descripción general de Central de empleados (EC)
# Solo para uso interno de SAP y socios
# Página 1 de 27
#
#
# Objetivos:
# Para habilitar/familiarizarse con la demostración de EC.
#
# Para utilizarlo como punto de partida para planificar su demostración de EC.
#
# Consejos y trucos:
# La simplicidad es buena. Considere simplificar su perfil de personas y su función de autoservicio de administrador para que se elimine todo lo que no sea relevante para su historia.
#
# Refleje el modelo de prestación de recursos humanos de su cliente potencial. Si trabajan con un centro de servicios compartido y socios comerciales de recursos humanos, es posible que desee reflejarlo en las definiciones de su flujo de trabajo.
#
# Preparación:
# ...

# %%
import openai

# Set up OpenAI API
openai.api_key = "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"

# Choose an LLM
model_engine = "davinci"

# Generate text using the LLM
text = """
Demo Script:
Employee Central Overview


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 1 of 27


Objectives:
To enable/familiarize yourself with demoing EC.

To use as a starting point for planning your EC demo.

Tips and Tricks:
Simplicity is good. Consider simplifying your People Profile and manager self-service role so that everything that isn’t relevant for your story is removed.

Reflect your prospect’s HR delivery model. If they work with a shared service center and HR business partners, you may want to reflect it in your workflow definitions.

Preparation:
Workflows - Correct the transfer without pay change workflow to remove the manager role so they are not the approver for the transaction (This is fixed in the 2018 Summer Release).

o HOW:
Log in as sfadmin
Go to Admin Tools -> Manage Organization, Pay and Job Structures
In the first drop down, select Workflow
In the second drop down, select XFER
In the upper right corner, select Take Action -> Make correction
In the first step of the workflow, change the context field from Target to Source

Scroll down and Save
Make sure an absence approval for the manager you’re using is available.

o HOW:
Login as the employee you will be using
From the Home Page, select the Time Off tile
Select the time off bucket at the top that you want to use (e.g. vacation or your regional equivalent)
Select 1 or several days in the future for the leave request
Select Submit. You will be notified that the request has gone to the manager for approval.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 2 of 27


Delete the transfer of the employee you’re using if necessary.

o HOW:
Log in as the manager who created the original transfer request
Go to Manage Pending Requests via Action Search
Select the employee you are using and go to their Employee Profile
Locate the requested transfer under My Requests Waiting for Approval
Select the request
Scroll Down and click on Withdraw at the bottom. Select Yes when prompted.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 3 of 27


As an admin, verify the absence balances available for the employee and make sure they’re meaningful. Update as necessary.

o HOW:
Login as sfadmin
In Action Search, enter Administer Time
Enter the employee name who you are using
You will then be in the Time Workbench
Select Time Accounts
Note the time balances for the account you want to use
If there are not enough days:
Scroll down to Account Postings
Select Add Manual Adjustment
Enter in number of days
Select Save


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 4 of 27


Before you start the mobile demo just go to the steps beforehand to make sure you have cached the main steps. Loading times can be long.

The user mentioned in the script reflects the German user in the NGD2 master (Version 1708). You can use the global and other local users in the same way. Make sure that the data and processes behave like expected.

Germany: Vanessa Wagner, Freda Hoch
France: Amelie Verrier, Coline Gage
UK: Sandra Gray, Liam Seaward
US: Mya Cooper, Gordon Elliston


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 5 of 27


Introduction:

The digital revolution heavily impacts the way we work. Companies have to become increasingly global to remain successful or to find talent in other regions. In addition, there’s a shift in technology. Artificial Intelligence (AI) will help us deliver more automation and improve self-service concepts. For commerce, as well as for HR, people will start communicating with chat bots to get their questions answered on the spot because we’ve gotten used to technologies provided by LinkedIn, Facebook or Twitter to collaborate and communicate on the spot.


If the expectations of employees are different, business models are different, and technology is different, what kind of answer should technology provide us? At SuccessFactors, we think that technology should allow us to be in continuous dialogue with employees. To connect people to the purpose of your business. The usage should be continuous (mobile), engagement should be continuous, and it should allow people to be able to ask HR questions 24/7.


Technology also needs to be extensible because we know that every company works slightly different. While the majority of HR processes are the same, for those that aren’t, companies can have the competitive edge to plan their workforce smarter, train them better or connect them to the goals of the organization in a unique way.


Above all, solutions need to be intelligent. When all HR processes are harmonized on one platform, the amount of data you’re capturing is huge. Modern technology such as Machine Learning (ML) allows you to use this data to suggest better training for your employees or to hire better because technology allows you to remove unconscious bias from your processes.


This allows companies to react very quickly to market demands and pressures. This connects people to purpose.


What if you could have a fully digital consumer grade HR experience…one that provides you a single core platform based on best practices and built on a global HR
template? A platform where employees and managers can use their mobile devices to get real-time updates and allow speed to task. What if you can use this technology to connect your people to your purpose? With our Employee Central solution, you can implement a global HR template, and of course keeping in mind local variances, take advantage of the deep localization concept that SuccessFactors deliver. Our Local Product Managers ensure your application remains up-to-date so that you can ensure compliance with ever changing law and regulations. We deliver this deep localization in 90+ countries around the globe.


Today we’ll look at Employee Central from three perspectives: as an employee, a manager and a HR Administrator illustrating how you can connect your people to your purpose.


Let’s start as a manager and assume you’re sitting on a train on your way to work. The same way you use your email, Amazon, or other Apps, the SuccessFactors App has become a regular companion in your daily work. Let’s see how…


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 6 of 27


Steps & Demo Tips
Message
Mobile
As with any other application, you receive notifications from the SuccessFactors (SF) App. This tells you the to-do’s and makes it easy for you to stay on top of your HR related tasks.

Vanessa Wagner (or
regional equivalent)
Open SF App


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 7 of 27


The intuitive user experience has been developed in tight partnership between SAP and Apple to make use of the impact on a mobile experience at its best.

To-Do site
Also, research shows that adding mobile capabilities provides 49% of employees with a better user experience of HR functions (Sierra-Cedar 2014–2015 HR Systems Survey White Paper) and HR organizations who embrace mobile applications outperform organizations that don’t.



Here you find a pending leave request, performance reviews and a summary review of your performance calibration meeting that requires your attention.


The App also makes you aware of new functionality you should try out. This embedded

education allows your users to quickly become familiar with the possibilities.



Your first to-do is a leave request so letś see what an approval workflow looks like.



Open Leave

Request


Here’s all the information you need for the approval request. The type of leave, the requested amount, and information on other absences from your team members.


You can see the duration of the request as well as who else is on a leave from your team in that timeframe. In one place, you get all the relevant information on which to make your decision.


This is a great example of a user experience that is simple and engaging.



Approve the
request

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 8 of 27


Time Off from the
Another common example on simplifying HR processes is the absence request.

More Menu
With the App, it’s easy to review all your own planned absences, entitlements and your team absence calendar to help you schedule your time off.

Select the +


You can attach documents or photos to your request. As an example, sending sick notes to your manager.

Select Annual

Leave (or your
A one-stop shop right at your fingertips!

regional

equivalent)


Select the start

and end dates



Select Send


Select the request


you just did


The App makes it not only easy to submit the request, but also helps you to block your calendar, delete appointments and automatically notify team members of your upcoming absence. These
Click on block
are intelligent, helpful services!

your calendar


Select ADD


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 9 of 27


Cancel

Then click on
Done

Pay Statement
After you decided to take some time off, it’s also a good idea to check your financials before booking a hotel.

With one click, you see your pay statement. With everything in one place, navigation is easy and intuitive. Go for the five-star hotel!


Beside these services, you’re also able to maintain your personal information. Let’s take a look at how easy it is.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 10 of 27


Profile
The profile gives you full transparency about your job, compensation and personal

information…and the ability to update your personal information.


The experience is designed to be intuitive for all employees in order to provide a quick and easy way of updating their information from wherever they are. Along with the outstanding user experience, you have improved data quality which is critical for driving accurate reporting.



From your profile, you can also directly access the org chart. The org chart gives you full
OrgChart
transparency into the organization with its solid and dotted reporting lines. The search

functionality allows you to have a look at all your colleagues.



From the profile, you can also change anything from your address, bank information, dependent data, down to your development and geographic work preferences. No need for emails, tickets, or phone calls.



Now that we’ve seen the employee experience, let’s see what you as the manager can view about your team.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 11 of 27


Team


The team view gives you direct access to information and actions on your team members and
Scroll down to
employee details.

Team location


For example, from your discussions with Freda ( Note: or regional equivalent) you know she wants to move to Berlin. Let's look to see how the team is distributed.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 12 of 27


You already have team members in Berlin, so she wouldn’t be alone there.



Go to Freda (or

Here you have transparency on Freda’s (or regional equivalent) current activities. You can assign regional
regular activities and topics for your next meeting with our Continuous Performance process equivalent)
(CPM). All activities and comments are captured with the SF App.



You know Freda (or regional equivalent) wants to move to Berlin and she’s added and

documented the topic prior to your last meeting using our Continuous Performance

Management platform (CPM). This allows you to track topics, activities, achievements and collect
Note: Add Topic
feedback, which can turn an annual backward-looking performance process into a forward
move to Berlin
looking…a value-added process.

before demo

(CPM)
From here you can initiate the transfer as part of Manager self-service.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 13 of 27


Click the three
The change can be effective at any time (past, now or future). For movement to another location dots
and job, your future date the change (i.e. first of next month).


Change Job and
Compensation

Info



Enter as of date

(e.g. Choose first

of next month)


Freda (or regional equivalent) takes over a vacant position you have in your team in Berlin. She’s going to work as Health and Safety manager.




Enter “Berlin

Health” (or the

regional

equivalent for the

position)

Note: The

position should

appear. When

there, select it.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 14 of 27



That’s it! You don’t have to do anything else. All attributes of the position automatically populate
the job information which This dramatically reduces maintenance efforts and makes even a
Scroll down to
complex HR process a consumable service for managers to do themselves.

Location and Job
Title
Why? The solution recognizes you want to initiate a transfer without a Pay Change and

automatically applies the prescribed business process for you. In the past, you had to know the HR process and select the right form.




Your HR Business Partner (in our example Tessa Walker or regional equivalent) will pick it up, review it and finalize it eliminating the paperwork or cumbersome administration often
associated with an HR transaction.

Save

After the request is approved, the data will change as of the effective date you have entered.



This mobile experience allows you to automate your processes with self-service in order to meet Show Workflow
today's and future requirements for digitalization and bring a consumable service environment participant
to your workforce.


"""
text1="""Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 15 of 27


Submit
To summarize…This mobile experience brings HR processes closer to your daily job. You saw how easy it is to maintain data as an employee as well as a manager. Making it simple to be in charge of your own data, you’ll increase the quality of it.



Now that you’ve seen how easy and intuitive the experience for managers and employees is, letś see how an HR Professional will work with SuccessFactors in order to improve HR services.



Steps & Demo Tips
Message
Login as
Here’s an example of the Home Page for a HR Professional. It gives you easy access to all Twalker (or
your to-dos and information is relevant for you, both as an employee/manager and as an
regional
HR Professional.

equivalent)


You could also share company news like upcoming HR events or policy changes, etc. It’s the perfect place to share information quickly and easily.


Show how to move
tiles and
personalize home
page
Click on “Approve
Let’s start with what you need to do right now. You see next to other requests the
Requests”
transfer Vanessa (or regional equivalent) just initiated. Let’s review the proposed changes.



Click on Filter


Here you see the requested change in detail and can open supporting information that
Click on “transfer
helps you in your decision making.

w/o pay change”

for Freda (or
The transaction is correct so you approve the request.

regional


equivalent)


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 16 of 27


Additionally, all the approvals can be filtered. As an HR Professional getting multiple requests per day, this allows you to search for workflows and easily navigate or answer


questions.



Approve


As you’ve already seen in the mobile experience, the approval directly changes the data so no further activity is requested. That improves the service of HR…for employees,
managers and you!



Another important aspect of having all data in one common HR platform is the quality of advice to your business leaders. Today only 52% of all leaders have data and analytics at their fingertips (Bersin by Deloitte Global Human Capital Trends 2016 report). Having
visibility into your data at a moment’s notice is critical.

Back to the home
One of Tessa’s (or regional equivalent) tasks is to monitor Key Performance Indicators page
(KPIs) and conduct ad-hoc queries.



In this example, great progress has been made in reducing termination rates. This looks
Click Link
good but you still want to know more; so, you dig a bit deeper.

Termination rate


You see the yearly development and a measurement against performance. This, too, looks good as you seem not to lose too many high performers.



Drilling down further, you want to know the exact calculation of the termination rate. This
Click Question
is one of the 2000 metrics that are predefined with Workforce Analytics. A subset,
mark icon
including this one, comes with Employee Central.


*( Note: WFA is not included with EC but you always want to show it during the demo.) Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 17 of 27


With these capabilities on people analytics, you gain the deep, real time insights you need
Analyze By
to credibly influence decision making and improve business results. -- Data at your
Select All Ages
fingertips!


You’re also able to analyze the data against different dimensions in order to understand impacts and challenges. For example, with age distribution, you see that your highest
termination rates are from the ages 30-39. This seems critical as these experienced
employees are the biggest source for new leaders. Tessa (or regional equivalent) will
explore this later, but this may be related to your latest survey, which indicated issues with child care and flexible working options. Besides the analysis of termination, Tessa (or regional equivalent) also received a request about equal pay in the organization.

Click Home Page
You want to analyse if the company pays equitably without any gender bias. Normally
Investigate
such a question couldn´t be answered without days of work and manually collecting data

from different sources.



Start new
Now you’re able to analyse the data…based on various metrics, dimensions, trends and
investigation
forecasting. The visualization allows to clearly communicate the findings.



Use search field
After the analysis is completed, the can be shared by simply downloading the results.

to…


Select Average

comp-ratio metric


Select gender

dimension


Select job

function

dimension
To deliver such insights and increase the quality of the advice to business leaders, it’s important to have all data in one common HR platform. With Employee Central you have

all data and HR processes in one place. Letś now look at the underlying data and HR
Click Analyze
processes in more detail.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 18 of 27


Type org chart in

This is the org chart that shows you the current reporting lines that we have already seen the action search

in mobile. It’s the “daily” entry point for your managers and employees, alike, providing detail on all employment relationships – permanent employees, contingent works, global


assignments. All within one view.



Search for Ralph

Brunnert (or

regional

equivalent)
Besides the manager/employee relationship, the solution also allows you to combine all organizational information through position management.



Your position data flows seamlessly throughout the solution, driving data and
Click on next tab:
processes in areas such as recruiting, succession and headcount planning. In one quick
Position org chart
view, you’re presented with a snapshot of your current capacity plan -- empowering
Search for people:
you to make critical business decisions based on possible headcount gaps and total
Ralph Brunnert
workforce utilization.

(or regional

Whenever someone is hired or transferred into a position like Freda (or regional
equivalent)

equivalent), the attributes of the position will flow to those of the employee’s job,

ensuring excellent data quality and eliminating extra manual work.

Click on his

position and

position hierarchy

details
Finally, span of control is visible which is an important KPI when we talk about

organizations, and also indicates the efficiency of the organizational set up.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 19 of 27


You can look at your organization in the future and the past. If the as of date is
Click on Today to
changed (1st of the next month) the chart reflects the transfer of Freda (or regional
show that
equivalent).

visualization can

be changed


(choose the date


that was used for


the position and


location change

Now that we’ve seen how the manager/employee relationship and Position
previously)

Management allows you to manage the workforce efficiently, letś review what an

organizational unit relationship looks like.



Click company
This view shows the org units in relation to each other. This can be either on a legal entity structure
basis or as we see here on a functional view.

overview
This view represents the functional structure of the company. Legal structures, cost center hierarchies, etc. can be visualized in the same way.

Click Business

View
Furthermore, you can add a new department directly on this view which allows you to

redesign your organization to drive organizational efficiency.

Select Business

Unit


The flexibility in Employee Central allows you to design your organizational structure in an
Select Products
agile way. The possibilities combine a best practice structure with Business Unit, Division and Department, as well as configurable organizational elements based on your specific
Open a division to
needs. This provides easy access to all relevant information about your organizational set show
up and the allocated people and positions.

departments


Now that we’ve seen the underlying organizational set up to gain better insight into your
Go back to home
organization, let’s look more into the details of your employee data and HR processes.

page

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 20 of 27


First, the employee profile where you can view an employee’s complete HR and talent
landscape.

Search for Freda
Core profile information can be split into different, configurable sections making all the (or regional
data available in one place.

equivalent) in
Depending on your permissions, the appropriate data like personal, employment, payroll action search and
and benefits information can be viewed and changed.

open the people
By combining core and talent data into one profile, managers, HR and employees
profile
themselves have a holistic view on all relevant data to make the right decisions.


This one stop shop concept allows for efficient and intuitive self-service, empowering and engaging your entire workforce.



In addition, one of our main advantages of Employee Central is the delivered localization.


We offer this for 89+ countries for personal information (address formats, IBAN, Social

Security, etc.); but, more importantly, for employment information. Every legal change

comes to you via the Upgrade Center. That’s critical for integration to payroll as well as for legal reporting, etc. This allows you to stay on track with no effort on your part.



Beside this unique offering of localization in the core HR solution, we also provide audit
Click on show
capabilities in alignment with the rules and regulations of General Data Protection
more in Personal
Regulation (GDPR).

Information

Click Clock Icon in
Here you have the full view of your employee’s job history in an easy to read format with job information
the changes on the left side and the details on the right, including date and originator of portal
the last change.


As the HR admin, you can easily update data here with all history available for audit

purposes.

Close the overlay

window
Additionally, retroactive adjustments will occur based on changes in the past and will trigger a payroll recalculation.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 21 of 27


Scroll to
Here you find the gross pay components of Freda (or regional equivalent) that are
compensation
contractually agreed upon (or based on a tariff, if applicable).

info
Additional graphs provide a quick snapshot of an employee’s compensation structure that provides key decision-making information for you/HR and the manager.



Click on a specific
Local payroll information can be maintained from the same screen, regardless of the SAP
regional example
Payroll solution you use.

for your country
( Note: Keep in mind that this is only valid for ECP or on-premise SAP HCM Payroll solutions (ex: Germany:
that are run by customers or partners like ADP, NGA.)

social insurance;

US: IRS Limits;
This is a great advantage for you/HR so data is visible and maintained from one place.

Australia:


Superannuation,

etc.)



Another advantage, especially when it comes to transactional processes, is the capability
Login: Twalker;
to also generate documents according to the processes.

Welcome1 (or
regional
equivalent)
Note: Keep in
mind you have to
log on every time
you try to open
this.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 22 of 27


Click Take action
Here’s where other processes are initiated and documents can be printed. These are
Show the action
guided activities for you as the HR person as well as managers using self -service.

which can be

taken


We’ve seen the employee data, how processes are initiated and how changes are
reviewed. Now let’s take a look at initiating a new hire into your HR solution.

Pending Hires in
SuccessFactors, being a full HR suite, makes it efficient and quick to hire a new employee Action Search
unlike the pain that is often experienced with siloed systems. Here you can simply verify the information collected during recruiting and onboarding with the option to add or
Click on
override as needed.

Recruiting>Select


Onboarding


During onboarding, your employee can complete all the necessary paperwork from which
Hire Ingrid
their verified information flows to their new hire record, eliminating duplicate entry and Schmid (or
ensuring data integrity.

regional

equivalent)
All HR processes provide an experience for your managers and employees which will

increase engagement and allows you as HR to optimize your service.



Go back to

homepage for the

overall summary
Today we saw how SuccessFactors Employee Central provides a fully digital consumer

grade HR experience. By using mobile at the beginning, we saw that our solution is

designed to be a full self-service solution which drives your automation and improves your

service as a HR Professional.



CLOSING
By combining all relevant data into one single source by using Employee Central, you as
HR can get insights and analytics to challenge people decisions with your business leaders.


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 23 of 27


Our best practices and innovations build the base for your digital transformation and will allow you to put people to the purpose of your company.

Optional: The following steps are optional according to your prospect’s opportunity
Steps & Demo Tips
Message
LOCALIZATION
One of the main differentiators for us is localization. Aside of implementing the solution,
Home>
we provide all compliance and regulatory changes around the world and ongoing
Employee
maintenance support.

Localization Tile
Can you image how much effort it would be for you to take over this maintenance by not using a global platform?



At the moment, we provide localizations for 89+ countries around the world as you can

see on this world map.


Besides general localizations, like currencies and national idś, we also provide all fields
Overview Map
requested by regulatory or compliance requirements.


Our team of Localization Product Managers ensures that we are on track with legal

changes around the world and we deliver those changes four times a year.



Note: Take a

Letś review these localizations.

country that fits

to your prospect’s

landscape>Go to

Localizations>Sho

w fields
Along with offering a variety of fields, we provide localized reports that we offer within the report repository.



With this localization, you’re able to run your solution on a global scale.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 24 of 27


UPGRADE CENTER
The application is built on a very powerful platform which is updated four times a year.

Back to SF
This ensures you’re current and can take advantage of new innovations we deliver.

Search for
Utilizing these new innovations doesn’t require alignment with your IT, defining upgrade upgrade center
projects, or new hardware investments anymore.

You can use our Upgrade Center to simply switch on the new innovations and to roll it out to your business. It’s just that easy!


This is also where you’ll find detailed information about upcoming new functionality
occurring every three months. If there’s new functionality that will provide your

organization value, you can perform the upgrade directly from here.

Our upgrades are split into mandatory and optional upgrades. We also provide best
practices within the Upgrade Center, allowing you to take advantage of pre-built content
from SuccessFactors. This content is based on customer successes.


For example,… ( Note: insert an EC customer story!)
TIME
Within SuccessFactors, we offer Employee Central Time and Attendance Management.

Go to time
This is a native part of Employee Central, so there’s no additional subscription.

section in profile

Administer Time>
The time work bench is your central place from which to monitor and adjust/correct
Time Accounts

employee’s time information as needed.


One of our biggest strengths within Employee Central Time Management is our ability to offer time management in compliance with local laws and regulations. We offer a
platform with many components and logic, such as holiday calendars, accrual rules,
business rules, etc. which you can use to be compliant with collective labor agreements,
and local and federal laws.


If your customer’s main purpose for time administration is to correctly pay people, EC
Time is a great solution. It handles all your employee absences and provides a correct
time evaluation to correctly pay your employees.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 25 of 27


BENEFITS
Employee Central also comes with a native Benefits Management solution. The Global
Back to People
Benefits framework is an intelligently designed system that is scalable, flexible and
profile
ensures delivery and management of benefits for any organization in any country.

Go to Benefits

Section>

Take for example “allowances” which is basically a fixed amount of money that’s available Benefits overview
to an employee to pay for something. It may not cover the whole cost but nevertheless,
there’s money put aside to allow for this expense. For example, in the Philippines, there’s a “rice bag allowance” or in some countries in EMEA, there’s an “allowance” set aside to
pay for warm clothing.


Our Global Benefits solution is flexible enough to enable you to implement your benefit
types by country and effectively enable employees to enroll, file a claim and get
reimbursed.


( Note: When required to position US Benefits work with your EC Solution Advisor.) EXTENSION CENTER
Every company is unique. Using the Extension Center, you can configure forms, business
Search for
logic and approval processes that meet your company’s specific needs.

Extension Center
There is a dedicated script here.



Through the SAP Cloud Platform, you can take advantage of applications developed in our ecosystem. In our Application store, you can locate some great examples of those

extensions like the Alumni Network.


To summarize:
• The partnerships allow you to extend the capabilities of our solution as needed to
meet your business needs via productized integrations and partner developed apps.

• Our partners also support you and us with deep implementation expertise and
accelerators.


• We call this collective capability the ‘Power of SAP’.

CLOSING 2

Today we saw how SuccessFactors Employee Central provides a fully digital consumer
grade HR experience. By using mobile at the beginning, we saw that our solution is
designed to be a full self-service solution which drives your automation and improves your service as a HR Professional.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 26 of 27


By combining all relevant data into one single source by using Employee Central, you as
HR can get insights and analytics to challenge people decisions with your business leaders.


Our best practices and innovations build the base for your digital transformation.


Localization ensures a scalable solution runs on a global level. Additionally, our Extension capabilities and ecosystem provides you with ‘The Power of SAP’.


All this together enables you to connect your people to the purpose of your company.

Additional topics to consider adding to your EC demo (Often these items are shown and can complement your demo) --
HR or system admin demo topics:
o Mass Changes
o Role Based Permissions (RBP)
o Intelligent Services/Integration Center
o Admin Center – Workflow/Data Alerts
o Business Configuration, New Fields
Global Mobility
Org Modelling (Nakisha/Ingenui’s)
Document Management (Open Text)
Contingent Labour

APPENDIX:

This Scripts was designed to support data and configurations for instance 1708

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 27 of 27"""

texts=[text,text1]
for i in range(len(texts)):
    prompt = f"""
    Translate english to spanish 

    Review: ```{texts[i]}```
    """

    response = get_completion(prompt)
    print(i, response, "\n")
# Out:
# 0 Revisión:
# ```
# Guion de demostración:
# Visión general de Employee Central
#
#
# Visión general de Employee Central (EC)
# Solo para uso interno de SAP y socios
# Página 1 de 27
#
#
# Objetivos:
# Permitir/familiarizarse con la demostración de EC.
#
# Utilizar como punto de partida para planificar su demostración de EC.
#
# Consejos y trucos:
# La simplicidad es buena. Considere simplificar su perfil de personas y el rol de autoservicio del gerente para eliminar todo lo que no sea relevante para su historia.
#
# Refleje el modelo de entrega de recursos humanos de su prospecto. Si trabajan con un centro de servicios compartidos y socios comerciales de recursos humanos, es posible que desee reflejarlo en sus definiciones de flujo de trabajo.
#
# Preparación:
# Flujos de trabajo: corrija el flujo de trabajo de cambio sin pago para eliminar el rol del gerente para que no sea el aprobador de la transacción (esto se soluciona en la versión de verano de 2018).
#
# o CÓMO:
# ...

# %%
# Define the input data
input_text = """
Demo Script:
Employee Central Overview


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 1 of 27


Objectives:
To enable/familiarize yourself with demoing EC.

To use as a starting point for planning your EC demo.

Tips and Tricks:
Simplicity is good. Consider simplifying your People Profile and manager self-service role so that everything that isn’t relevant for your story is removed.

Reflect your prospect’s HR delivery model. If they work with a shared service center and HR business partners, you may want to reflect it in your workflow definitions.

Preparation:
Workflows - Correct the transfer without pay change workflow to remove the manager role so they are not the approver for the transaction (This is fixed in the 2018 Summer Release).

o HOW:
Log in as sfadmin
Go to Admin Tools -> Manage Organization, Pay and Job Structures
In the first drop down, select Workflow
In the second drop down, select XFER
In the upper right corner, select Take Action -> Make correction
In the first step of the workflow, change the context field from Target to Source

Scroll down and Save
Make sure an absence approval for the manager you’re using is available.

o HOW:
Login as the employee you will be using
From the Home Page, select the Time Off tile
Select the time off bucket at the top that you want to use (e.g. vacation or your regional equivalent)
Select 1 or several days in the future for the leave request
Select Submit. You will be notified that the request has gone to the manager for approval.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 2 of 27


Delete the transfer of the employee you’re using if necessary.

o HOW:
Log in as the manager who created the original transfer request
Go to Manage Pending Requests via Action Search
Select the employee you are using and go to their Employee Profile
Locate the requested transfer under My Requests Waiting for Approval
Select the request
Scroll Down and click on Withdraw at the bottom. Select Yes when prompted.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 3 of 27


As an admin, verify the absence balances available for the employee and make sure they’re meaningful. Update as necessary.

o HOW:
Login as sfadmin
In Action Search, enter Administer Time
Enter the employee name who you are using
You will then be in the Time Workbench
Select Time Accounts
Note the time balances for the account you want to use
If there are not enough days:
Scroll down to Account Postings
Select Add Manual Adjustment
Enter in number of days
Select Save


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 4 of 27


Before you start the mobile demo just go to the steps beforehand to make sure you have cached the main steps. Loading times can be long.

The user mentioned in the script reflects the German user in the NGD2 master (Version 1708). You can use the global and other local users in the same way. Make sure that the data and processes behave like expected.

Germany: Vanessa Wagner, Freda Hoch
France: Amelie Verrier, Coline Gage
UK: Sandra Gray, Liam Seaward
US: Mya Cooper, Gordon Elliston


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 5 of 27


Introduction:

The digital revolution heavily impacts the way we work. Companies have to become increasingly global to remain successful or to find talent in other regions. In addition, there’s a shift in technology. Artificial Intelligence (AI) will help us deliver more automation and improve self-service concepts. For commerce, as well as for HR, people will start communicating with chat bots to get their questions answered on the spot because we’ve gotten used to technologies provided by LinkedIn, Facebook or Twitter to collaborate and communicate on the spot.


If the expectations of employees are different, business models are different, and technology is different, what kind of answer should technology provide us? At SuccessFactors, we think that technology should allow us to be in continuous dialogue with employees. To connect people to the purpose of your business. The usage should be continuous (mobile), engagement should be continuous, and it should allow people to be able to ask HR questions 24/7.


Technology also needs to be extensible because we know that every company works slightly different. While the majority of HR processes are the same, for those that aren’t, companies can have the competitive edge to plan their workforce smarter, train them better or connect them to the goals of the organization in a unique way.


Above all, solutions need to be intelligent. When all HR processes are harmonized on one platform, the amount of data you’re capturing is huge. Modern technology such as Machine Learning (ML) allows you to use this data to suggest better training for your employees or to hire better because technology allows you to remove unconscious bias from your processes.


This allows companies to react very quickly to market demands and pressures. This connects people to purpose.


What if you could have a fully digital consumer grade HR experience…one that provides you a single core platform based on best practices and built on a global HR
template? A platform where employees and managers can use their mobile devices to get real-time updates and allow speed to task. What if you can use this technology to connect your people to your purpose? With our Employee Central solution, you can implement a global HR template, and of course keeping in mind local variances, take advantage of the deep localization concept that SuccessFactors deliver. Our Local Product Managers ensure your application remains up-to-date so that you can ensure compliance with ever changing law and regulations. We deliver this deep localization in 90+ countries around the globe.


Today we’ll look at Employee Central from three perspectives: as an employee, a manager and a HR Administrator illustrating how you can connect your people to your purpose.


Let’s start as a manager and assume you’re sitting on a train on your way to work. The same way you use your email, Amazon, or other Apps, the SuccessFactors App has become a regular companion in your daily work. Let’s see how…


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 6 of 27


Steps & Demo Tips
Message
Mobile
As with any other application, you receive notifications from the SuccessFactors (SF) App. This tells you the to-do’s and makes it easy for you to stay on top of your HR related tasks.

Vanessa Wagner (or
regional equivalent)
Open SF App


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 7 of 27


The intuitive user experience has been developed in tight partnership between SAP and Apple to make use of the impact on a mobile experience at its best.

To-Do site
Also, research shows that adding mobile capabilities provides 49% of employees with a better user experience of HR functions (Sierra-Cedar 2014–2015 HR Systems Survey White Paper) and HR organizations who embrace mobile applications outperform organizations that don’t.



Here you find a pending leave request, performance reviews and a summary review of your performance calibration meeting that requires your attention.


The App also makes you aware of new functionality you should try out. This embedded

education allows your users to quickly become familiar with the possibilities.



Your first to-do is a leave request so letś see what an approval workflow looks like.



Open Leave

Request


Here’s all the information you need for the approval request. The type of leave, the requested amount, and information on other absences from your team members.


You can see the duration of the request as well as who else is on a leave from your team in that timeframe. In one place, you get all the relevant information on which to make your decision.


This is a great example of a user experience that is simple and engaging.



Approve the
request

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 8 of 27


Time Off from the
Another common example on simplifying HR processes is the absence request.

More Menu
With the App, it’s easy to review all your own planned absences, entitlements and your team absence calendar to help you schedule your time off.

Select the +


You can attach documents or photos to your request. As an example, sending sick notes to your manager.

Select Annual

Leave (or your
A one-stop shop right at your fingertips!

regional

equivalent)


Select the start

and end dates



Select Send


Select the request


you just did


The App makes it not only easy to submit the request, but also helps you to block your calendar, delete appointments and automatically notify team members of your upcoming absence. These
Click on block
are intelligent, helpful services!

your calendar


Select ADD


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 9 of 27


Cancel

Then click on
Done

Pay Statement
After you decided to take some time off, it’s also a good idea to check your financials before booking a hotel.

With one click, you see your pay statement. With everything in one place, navigation is easy and intuitive. Go for the five-star hotel!


Beside these services, you’re also able to maintain your personal information. Let’s take a look at how easy it is.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 10 of 27


Profile
The profile gives you full transparency about your job, compensation and personal

information…and the ability to update your personal information.


The experience is designed to be intuitive for all employees in order to provide a quick and easy way of updating their information from wherever they are. Along with the outstanding user experience, you have improved data quality which is critical for driving accurate reporting.



From your profile, you can also directly access the org chart. The org chart gives you full
OrgChart
transparency into the organization with its solid and dotted reporting lines. The search

functionality allows you to have a look at all your colleagues.



From the profile, you can also change anything from your address, bank information, dependent data, down to your development and geographic work preferences. No need for emails, tickets, or phone calls.



Now that we’ve seen the employee experience, let’s see what you as the manager can view about your team.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 11 of 27


Team


The team view gives you direct access to information and actions on your team members and
Scroll down to
employee details.

Team location


For example, from your discussions with Freda ( Note: or regional equivalent) you know she wants to move to Berlin. Let's look to see how the team is distributed.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 12 of 27


You already have team members in Berlin, so she wouldn’t be alone there.



Go to Freda (or

Here you have transparency on Freda’s (or regional equivalent) current activities. You can assign regional
regular activities and topics for your next meeting with our Continuous Performance process equivalent)
(CPM). All activities and comments are captured with the SF App.



You know Freda (or regional equivalent) wants to move to Berlin and she’s added and

documented the topic prior to your last meeting using our Continuous Performance

Management platform (CPM). This allows you to track topics, activities, achievements and collect
Note: Add Topic
feedback, which can turn an annual backward-looking performance process into a forward
move to Berlin
looking…a value-added process.

before demo

(CPM)
From here you can initiate the transfer as part of Manager self-service.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 13 of 27


Click the three
The change can be effective at any time (past, now or future). For movement to another location dots
and job, your future date the change (i.e. first of next month).


Change Job and
Compensation

Info



Enter as of date

(e.g. Choose first

of next month)


Freda (or regional equivalent) takes over a vacant position you have in your team in Berlin. She’s going to work as Health and Safety manager.




Enter “Berlin

Health” (or the

regional

equivalent for the

position)

Note: The

position should

appear. When

there, select it.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 14 of 27



That’s it! You don’t have to do anything else. All attributes of the position automatically populate
the job information which This dramatically reduces maintenance efforts and makes even a
Scroll down to
complex HR process a consumable service for managers to do themselves.

Location and Job
Title
Why? The solution recognizes you want to initiate a transfer without a Pay Change and

automatically applies the prescribed business process for you. In the past, you had to know the HR process and select the right form.




Your HR Business Partner (in our example Tessa Walker or regional equivalent) will pick it up, review it and finalize it eliminating the paperwork or cumbersome administration often
associated with an HR transaction.

Save

After the request is approved, the data will change as of the effective date you have entered.



This mobile experience allows you to automate your processes with self-service in order to meet Show Workflow
today's and future requirements for digitalization and bring a consumable service environment participant
to your workforce.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 15 of 27


Submit
To summarize…This mobile experience brings HR processes closer to your daily job. You saw how easy it is to maintain data as an employee as well as a manager. Making it simple to be in charge of your own data, you’ll increase the quality of it.



Now that you’ve seen how easy and intuitive the experience for managers and employees is, letś see how an HR Professional will work with SuccessFactors in order to improve HR services.



Steps & Demo Tips
Message
Login as
Here’s an example of the Home Page for a HR Professional. It gives you easy access to all Twalker (or
your to-dos and information is relevant for you, both as an employee/manager and as an
regional
HR Professional.

equivalent)


You could also share company news like upcoming HR events or policy changes, etc. It’s the perfect place to share information quickly and easily.


Show how to move
tiles and
personalize home
page
Click on “Approve
Let’s start with what you need to do right now. You see next to other requests the
Requests”
transfer Vanessa (or regional equivalent) just initiated. Let’s review the proposed changes.



Click on Filter


Here you see the requested change in detail and can open supporting information that
Click on “transfer
helps you in your decision making.

w/o pay change”

for Freda (or
The transaction is correct so you approve the request.

regional


equivalent)


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 16 of 27


Additionally, all the approvals can be filtered. As an HR Professional getting multiple requests per day, this allows you to search for workflows and easily navigate or answer


questions.



Approve


As you’ve already seen in the mobile experience, the approval directly changes the data so no further activity is requested. That improves the service of HR…for employees,
managers and you!



Another important aspect of having all data in one common HR platform is the quality of advice to your business leaders. Today only 52% of all leaders have data and analytics at their fingertips (Bersin by Deloitte Global Human Capital Trends 2016 report). Having
visibility into your data at a moment’s notice is critical.

Back to the home
One of Tessa’s (or regional equivalent) tasks is to monitor Key Performance Indicators page
(KPIs) and conduct ad-hoc queries.



In this example, great progress has been made in reducing termination rates. This looks
Click Link
good but you still want to know more; so, you dig a bit deeper.

Termination rate


You see the yearly development and a measurement against performance. This, too, looks good as you seem not to lose too many high performers.



Drilling down further, you want to know the exact calculation of the termination rate. This
Click Question
is one of the 2000 metrics that are predefined with Workforce Analytics. A subset,
mark icon
including this one, comes with Employee Central.


*( Note: WFA is not included with EC but you always want to show it during the demo.) Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 17 of 27


With these capabilities on people analytics, you gain the deep, real time insights you need
Analyze By
to credibly influence decision making and improve business results. -- Data at your
Select All Ages
fingertips!


You’re also able to analyze the data against different dimensions in order to understand impacts and challenges. For example, with age distribution, you see that your highest
termination rates are from the ages 30-39. This seems critical as these experienced
employees are the biggest source for new leaders. Tessa (or regional equivalent) will
explore this later, but this may be related to your latest survey, which indicated issues with child care and flexible working options. Besides the analysis of termination, Tessa (or regional equivalent) also received a request about equal pay in the organization.

Click Home Page
You want to analyse if the company pays equitably without any gender bias. Normally
Investigate
such a question couldn´t be answered without days of work and manually collecting data

from different sources.



Start new
Now you’re able to analyse the data…based on various metrics, dimensions, trends and
investigation
forecasting. The visualization allows to clearly communicate the findings.



Use search field
After the analysis is completed, the can be shared by simply downloading the results.

to…


Select Average

comp-ratio metric


Select gender

dimension


Select job

function

dimension
To deliver such insights and increase the quality of the advice to business leaders, it’s important to have all data in one common HR platform. With Employee Central you have

all data and HR processes in one place. Letś now look at the underlying data and HR
Click Analyze
processes in more detail.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 18 of 27


Type org chart in

This is the org chart that shows you the current reporting lines that we have already seen the action search

in mobile. It’s the “daily” entry point for your managers and employees, alike, providing detail on all employment relationships – permanent employees, contingent works, global


assignments. All within one view.



Search for Ralph

Brunnert (or

regional

equivalent)
Besides the manager/employee relationship, the solution also allows you to combine all organizational information through position management.



Your position data flows seamlessly throughout the solution, driving data and
Click on next tab:
processes in areas such as recruiting, succession and headcount planning. In one quick
Position org chart
view, you’re presented with a snapshot of your current capacity plan -- empowering
Search for people:
you to make critical business decisions based on possible headcount gaps and total
Ralph Brunnert
workforce utilization.

(or regional

Whenever someone is hired or transferred into a position like Freda (or regional
equivalent)

equivalent), the attributes of the position will flow to those of the employee’s job,

ensuring excellent data quality and eliminating extra manual work.

Click on his

position and

position hierarchy

details
Finally, span of control is visible which is an important KPI when we talk about

organizations, and also indicates the efficiency of the organizational set up.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 19 of 27


You can look at your organization in the future and the past. If the as of date is
Click on Today to
changed (1st of the next month) the chart reflects the transfer of Freda (or regional
show that
equivalent).

visualization can

be changed


(choose the date


that was used for


the position and


location change

Now that we’ve seen how the manager/employee relationship and Position
previously)

Management allows you to manage the workforce efficiently, letś review what an

organizational unit relationship looks like.



Click company
This view shows the org units in relation to each other. This can be either on a legal entity structure
basis or as we see here on a functional view.

overview
This view represents the functional structure of the company. Legal structures, cost center hierarchies, etc. can be visualized in the same way.

Click Business

View
Furthermore, you can add a new department directly on this view which allows you to

redesign your organization to drive organizational efficiency.

Select Business

Unit


The flexibility in Employee Central allows you to design your organizational structure in an
Select Products
agile way. The possibilities combine a best practice structure with Business Unit, Division and Department, as well as configurable organizational elements based on your specific
Open a division to
needs. This provides easy access to all relevant information about your organizational set show
up and the allocated people and positions.

departments


Now that we’ve seen the underlying organizational set up to gain better insight into your
Go back to home
organization, let’s look more into the details of your employee data and HR processes.

page

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 20 of 27


First, the employee profile where you can view an employee’s complete HR and talent
landscape.

Search for Freda
Core profile information can be split into different, configurable sections making all the (or regional
data available in one place.

equivalent) in
Depending on your permissions, the appropriate data like personal, employment, payroll action search and
and benefits information can be viewed and changed.

open the people
By combining core and talent data into one profile, managers, HR and employees
profile
themselves have a holistic view on all relevant data to make the right decisions.


This one stop shop concept allows for efficient and intuitive self-service, empowering and engaging your entire workforce.



In addition, one of our main advantages of Employee Central is the delivered localization.


We offer this for 89+ countries for personal information (address formats, IBAN, Social

Security, etc.); but, more importantly, for employment information. Every legal change

comes to you via the Upgrade Center. That’s critical for integration to payroll as well as for legal reporting, etc. This allows you to stay on track with no effort on your part.



Beside this unique offering of localization in the core HR solution, we also provide audit
Click on show
capabilities in alignment with the rules and regulations of General Data Protection
more in Personal
Regulation (GDPR).

Information

Click Clock Icon in
Here you have the full view of your employee’s job history in an easy to read format with job information
the changes on the left side and the details on the right, including date and originator of portal
the last change.


As the HR admin, you can easily update data here with all history available for audit

purposes.

Close the overlay

window
Additionally, retroactive adjustments will occur based on changes in the past and will trigger a payroll recalculation.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 21 of 27


Scroll to
Here you find the gross pay components of Freda (or regional equivalent) that are
compensation
contractually agreed upon (or based on a tariff, if applicable).

info
Additional graphs provide a quick snapshot of an employee’s compensation structure that provides key decision-making information for you/HR and the manager.



Click on a specific
Local payroll information can be maintained from the same screen, regardless of the SAP
regional example
Payroll solution you use.

for your country
( Note: Keep in mind that this is only valid for ECP or on-premise SAP HCM Payroll solutions (ex: Germany:
that are run by customers or partners like ADP, NGA.)

social insurance;

US: IRS Limits;
This is a great advantage for you/HR so data is visible and maintained from one place.

Australia:


Superannuation,

etc.)



Another advantage, especially when it comes to transactional processes, is the capability
Login: Twalker;
to also generate documents according to the processes.

Welcome1 (or
regional
equivalent)
Note: Keep in
mind you have to
log on every time
you try to open
this.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 22 of 27


Click Take action
Here’s where other processes are initiated and documents can be printed. These are
Show the action
guided activities for you as the HR person as well as managers using self -service.

which can be

taken


We’ve seen the employee data, how processes are initiated and how changes are
reviewed. Now let’s take a look at initiating a new hire into your HR solution.

Pending Hires in
SuccessFactors, being a full HR suite, makes it efficient and quick to hire a new employee Action Search
unlike the pain that is often experienced with siloed systems. Here you can simply verify the information collected during recruiting and onboarding with the option to add or
Click on
override as needed.

Recruiting>Select


Onboarding


During onboarding, your employee can complete all the necessary paperwork from which
Hire Ingrid
their verified information flows to their new hire record, eliminating duplicate entry and Schmid (or
ensuring data integrity.

regional

equivalent)
All HR processes provide an experience for your managers and employees which will

increase engagement and allows you as HR to optimize your service.



Go back to

homepage for the

overall summary
Today we saw how SuccessFactors Employee Central provides a fully digital consumer

grade HR experience. By using mobile at the beginning, we saw that our solution is

designed to be a full self-service solution which drives your automation and improves your

service as a HR Professional.



CLOSING
By combining all relevant data into one single source by using Employee Central, you as
HR can get insights and analytics to challenge people decisions with your business leaders.


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 23 of 27


Our best practices and innovations build the base for your digital transformation and will allow you to put people to the purpose of your company.

Optional: The following steps are optional according to your prospect’s opportunity
Steps & Demo Tips
Message
LOCALIZATION
One of the main differentiators for us is localization. Aside of implementing the solution,
Home>
we provide all compliance and regulatory changes around the world and ongoing
Employee
maintenance support.

Localization Tile
Can you image how much effort it would be for you to take over this maintenance by not using a global platform?



At the moment, we provide localizations for 89+ countries around the world as you can

see on this world map.


Besides general localizations, like currencies and national idś, we also provide all fields
Overview Map
requested by regulatory or compliance requirements.


Our team of Localization Product Managers ensures that we are on track with legal

changes around the world and we deliver those changes four times a year.



Note: Take a

Letś review these localizations.

country that fits

to your prospect’s

landscape>Go to

Localizations>Sho

w fields
Along with offering a variety of fields, we provide localized reports that we offer within the report repository.



With this localization, you’re able to run your solution on a global scale.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 24 of 27


UPGRADE CENTER
The application is built on a very powerful platform which is updated four times a year.

Back to SF
This ensures you’re current and can take advantage of new innovations we deliver.

Search for
Utilizing these new innovations doesn’t require alignment with your IT, defining upgrade upgrade center
projects, or new hardware investments anymore.

You can use our Upgrade Center to simply switch on the new innovations and to roll it out to your business. It’s just that easy!


This is also where you’ll find detailed information about upcoming new functionality
occurring every three months. If there’s new functionality that will provide your

organization value, you can perform the upgrade directly from here.

Our upgrades are split into mandatory and optional upgrades. We also provide best
practices within the Upgrade Center, allowing you to take advantage of pre-built content
from SuccessFactors. This content is based on customer successes.


For example,… ( Note: insert an EC customer story!)
TIME
Within SuccessFactors, we offer Employee Central Time and Attendance Management.

Go to time
This is a native part of Employee Central, so there’s no additional subscription.

section in profile

Administer Time>
The time work bench is your central place from which to monitor and adjust/correct
Time Accounts

employee’s time information as needed.


One of our biggest strengths within Employee Central Time Management is our ability to offer time management in compliance with local laws and regulations. We offer a
platform with many components and logic, such as holiday calendars, accrual rules,
business rules, etc. which you can use to be compliant with collective labor agreements,
and local and federal laws.


If your customer’s main purpose for time administration is to correctly pay people, EC
Time is a great solution. It handles all your employee absences and provides a correct
time evaluation to correctly pay your employees.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 25 of 27


BENEFITS
Employee Central also comes with a native Benefits Management solution. The Global
Back to People
Benefits framework is an intelligently designed system that is scalable, flexible and
profile
ensures delivery and management of benefits for any organization in any country.

Go to Benefits

Section>

Take for example “allowances” which is basically a fixed amount of money that’s available Benefits overview
to an employee to pay for something. It may not cover the whole cost but nevertheless,
there’s money put aside to allow for this expense. For example, in the Philippines, there’s a “rice bag allowance” or in some countries in EMEA, there’s an “allowance” set aside to
pay for warm clothing.


Our Global Benefits solution is flexible enough to enable you to implement your benefit
types by country and effectively enable employees to enroll, file a claim and get
reimbursed.


( Note: When required to position US Benefits work with your EC Solution Advisor.) EXTENSION CENTER
Every company is unique. Using the Extension Center, you can configure forms, business
Search for
logic and approval processes that meet your company’s specific needs.

Extension Center
There is a dedicated script here.



Through the SAP Cloud Platform, you can take advantage of applications developed in our ecosystem. In our Application store, you can locate some great examples of those

extensions like the Alumni Network.


To summarize:
• The partnerships allow you to extend the capabilities of our solution as needed to
meet your business needs via productized integrations and partner developed apps.

• Our partners also support you and us with deep implementation expertise and
accelerators.


• We call this collective capability the ‘Power of SAP’.

CLOSING 2

Today we saw how SuccessFactors Employee Central provides a fully digital consumer
grade HR experience. By using mobile at the beginning, we saw that our solution is
designed to be a full self-service solution which drives your automation and improves your service as a HR Professional.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 26 of 27


By combining all relevant data into one single source by using Employee Central, you as
HR can get insights and analytics to challenge people decisions with your business leaders.


Our best practices and innovations build the base for your digital transformation.


Localization ensures a scalable solution runs on a global level. Additionally, our Extension capabilities and ecosystem provides you with ‘The Power of SAP’.


All this together enables you to connect your people to the purpose of your company.

Additional topics to consider adding to your EC demo (Often these items are shown and can complement your demo) --
HR or system admin demo topics:
o Mass Changes
o Role Based Permissions (RBP)
o Intelligent Services/Integration Center
o Admin Center – Workflow/Data Alerts
o Business Configuration, New Fields
Global Mobility
Org Modelling (Nakisha/Ingenui’s)
Document Management (Open Text)
Contingent Labour

APPENDIX:

This Scripts was designed to support data and configurations for instance 1708

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 27 of 27



"""
prompt = f"Translate '{input_text}' to Spanish:"
# Generate the localized text
generated_text = """
Guión de demostración:
Descripción general de la central de empleados


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 1 de 27


Objetivos:
Para habilitar/familiarizarse con la demostración de EC.

Para utilizarlo como punto de partida para planificar su demostración de EC.

Consejos y trucos:
La simplicidad es buena. Considere simplificar su perfil de personas y su función de autoservicio de administrador para que se elimine todo lo que no sea relevante para su historia.

Refleje el modelo de prestación de recursos humanos de su cliente potencial. Si trabajan con un centro de servicios compartido y socios comerciales de recursos humanos, es posible que desee reflejarlo en las definiciones de su flujo de trabajo.

Preparación:
Flujos de trabajo: corrija el flujo de trabajo de transferencia sin cambio de pago para eliminar la función de administrador para que no sea el aprobador de la transacción (esto se solucionó en la versión de verano de 2018).

o CÓMO:
Inicia sesión como sfadmin
Vaya a Herramientas de administración -> Administrar estructuras organizativas, salariales y laborales
En el primer menú desplegable, seleccione Flujo de trabajo
En el segundo menú desplegable, seleccione XFER
En la esquina superior derecha, seleccione Tomar acción -> Hacer corrección
En el primer paso del flujo de trabajo, cambie el campo de contexto de Destino a Origen

Desplácese hacia abajo y guarde
Asegúrese de que esté disponible una aprobación de ausencia para el administrador que está utilizando.

o CÓMO:
Inicie sesión como el empleado que utilizará
Desde la página de inicio, seleccione el mosaico Tiempo libre
Seleccione el período de tiempo libre en la parte superior que desea utilizar (por ejemplo, vacaciones o su equivalente regional)
Seleccione 1 o varios días en el futuro para la solicitud de licencia
Seleccione Enviar. Se le notificará que la solicitud ha llegado al gerente para su aprobación.

Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 2 de 27


Elimina la transferencia del empleado que estás utilizando si es necesario.

o CÓMO:
Inicie sesión como el administrador que creó la solicitud de transferencia original
Vaya a Administrar solicitudes pendientes a través de Búsqueda de acciones
Seleccione el empleado que está utilizando y vaya a su Perfil de empleado
Localice la transferencia solicitada en Mis solicitudes en espera de aprobación.
Seleccione la solicitud
Desplácese hacia abajo y haga clic en Retirar en la parte inferior. Seleccione Sí cuando se le solicite.



Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 3 de 27


Como administrador, verifique los saldos de ausencia disponibles para el empleado y asegúrese de que sean significativos. Actualice según sea necesario.

o CÓMO:
Iniciar sesión como sfadmin
En Action Search, ingrese Administrar tiempo
Ingrese el nombre del empleado que está utilizando
Entonces estarás en el Time Workbench.
Seleccionar cuentas de tiempo
Anote los saldos de tiempo de la cuenta que desea utilizar
Si no hay suficientes días:
Desplácese hacia abajo hasta Publicaciones de cuenta
Seleccione Agregar ajuste manual
Ingrese en número de días
Seleccione Guardar


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 4 de 27


Antes de comenzar la demostración móvil, simplemente siga los pasos anteriores para asegurarse de haber almacenado en caché los pasos principales. Los tiempos de carga pueden ser largos.

El usuario mencionado en el script refleja el usuario alemán en el maestro NGD2 (Versión 1708). Puede utilizar los usuarios globales y otros usuarios locales de la misma manera. Asegúrese de que los datos y los procesos se comporten como se esperaba.

Alemania: Vanessa Wagner, Freda Hoch
Francia: Amelie Verrier, Coline Gage
Reino Unido: Sandra Gray, Liam Seaward
Estados Unidos: Mya Cooper, Gordon Elliston


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 5 de 27
Introducción:

La revolución digital impacta fuertemente la forma en que trabajamos. Las empresas tienen que volverse cada vez más globales para seguir teniendo éxito o encontrar talento en otras regiones. Además, hay un cambio en la tecnología. La Inteligencia Artificial (IA) nos ayudará a ofrecer más automatización y mejorar los conceptos de autoservicio. Para el comercio, así como para los recursos humanos, las personas comenzarán a comunicarse con chatbots para obtener respuestas a sus preguntas en el momento porque nos hemos acostumbrado a las tecnologías proporcionadas por LinkedIn, Facebook o Twitter para colaborar y comunicarnos en el momento.


Si las expectativas de los empleados son diferentes, los modelos de negocio son diferentes y la tecnología es diferente, ¿qué tipo de respuesta debería darnos la tecnología? En SuccessFactors pensamos que la tecnología debería permitirnos estar en diálogo continuo con los empleados. Conectar a las personas con el propósito de su negocio. El uso debe ser continuo (móvil), la participación debe ser continua y debe permitir que las personas puedan hacer preguntas sobre RR.HH. las 24 horas del día, los 7 días de la semana.


La tecnología también debe ser extensible porque sabemos que cada empresa funciona de manera ligeramente diferente. Si bien la mayoría de los procesos de recursos humanos son los mismos, para aquellos que no lo son, las empresas pueden tener la ventaja competitiva para planificar su fuerza laboral de manera más inteligente, capacitarlos mejor o conectarlos con los objetivos de la organización de una manera única.


Por encima de todo, las soluciones deben ser inteligentes. Cuando todos los procesos de recursos humanos están armonizados en una plataforma, la cantidad de datos que se capturan es enorme. La tecnología moderna, como el aprendizaje automático (ML), le permite utilizar estos datos para sugerir una mejor capacitación para sus empleados o contratar mejores porque la tecnología le permite eliminar sesgos inconscientes de sus procesos.


Esto permite a las empresas reaccionar muy rápidamente a las demandas y presiones del mercado. Esto conecta a las personas con un propósito.


¿Qué pasaría si pudiera tener una experiencia de recursos humanos totalmente digital para el consumidor... una que le proporcione una plataforma central única basada en las mejores prácticas y construida sobre una base de recursos humanos global?
¿plantilla? Una plataforma donde los empleados y gerentes pueden usar sus dispositivos móviles para obtener actualizaciones en tiempo real y acelerar las tareas. ¿Qué pasaría si pudiera utilizar esta tecnología para conectar a su gente con su propósito? Con nuestra solución Employee Central, puede implementar una plantilla global de recursos humanos y, por supuesto, teniendo en cuenta las variaciones locales, aprovechar el profundo concepto de localización que ofrece SuccessFactors. Nuestros gerentes de productos locales se aseguran de que su aplicación se mantenga actualizada para que usted pueda garantizar el cumplimiento de las leyes y regulaciones en constante cambio. Ofrecemos esta localización profunda en más de 90 países de todo el mundo.


Hoy veremos Employee Central desde tres perspectivas: como empleado, gerente y administrador de recursos humanos, lo que ilustra cómo puede conectar a su gente con su propósito.


Comencemos como gerente y supongamos que está sentado en un tren camino al trabajo. De la misma manera que utiliza su correo electrónico, Amazon u otras aplicaciones, la aplicación SuccessFactors se ha convertido en un compañero habitual en su trabajo diario. Veamos cómo…


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 6 de 27


Pasos y consejos de demostración
Mensaje
Móvil
Al igual que con cualquier otra aplicación, recibe notificaciones de la aplicación SuccessFactors (SF). Esto le indica las tareas pendientes y le facilita mantenerse al tanto de sus tareas relacionadas con RR.HH.

Vanessa Wagner (o
equivalente regional)
Abrir aplicación SF


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 7 de 27


La experiencia de usuario intuitiva se ha desarrollado en estrecha colaboración entre SAP y Apple para aprovechar al máximo el impacto en una experiencia móvil.

Sitio de tareas pendientes
Además, las investigaciones muestran que agregar capacidades móviles proporciona al 49% de los empleados una mejor experiencia de usuario de las funciones de recursos humanos (Documento técnico de la encuesta sobre sistemas de recursos humanos de Sierra-Cedar 2014-2015) y las organizaciones de recursos humanos que adoptan aplicaciones móviles superan a las organizaciones que no lo hacen.



Aquí encontrará una solicitud de licencia pendiente, revisiones de desempeño y una revisión resumida de su reunión de calibración de desempeño que requiere su atención.


La aplicación también le informa sobre nuevas funciones que debe probar. esto incrustado

La educación permite a sus usuarios familiarizarse rápidamente con las posibilidades.



Su primera tarea pendiente es una solicitud de permiso, así que veamos cómo se ve un flujo de trabajo de aprobación.



Licencia abierta

Pedido


Aquí encontrará toda la información que necesita para la solicitud de aprobación. El tipo de licencia, el monto solicitado e información sobre otras ausencias de los miembros de su equipo.


Puede ver la duración de la solicitud y quién más está de licencia de su equipo en ese período de tiempo. En un solo lugar, obtienes toda la información relevante para tomar tu decisión.


Este es un gran ejemplo de una experiencia de usuario simple y atractiva.



Aprobar el
pedido

Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 8 de 27


Tiempo libre de la
Otro ejemplo común de simplificación de los procesos de recursos humanos es la solicitud de ausencia.

Más menú
Con la aplicación, es fácil revisar todas tus ausencias planificadas, tus derechos y el calendario de ausencias de tu equipo para ayudarte a programar tu tiempo libre.

Seleccione el +


Puede adjuntar documentos o fotografías a su solicitud. Por ejemplo, enviar notas de enfermedad a su gerente.

Seleccionar Anual

Deja (o tu
¡Una ventanilla única al alcance de tu mano!

regional

equivalente)


Selecciona el inicio

y fechas de finalización



Seleccione Enviar


Seleccione la solicitud


solo lo hiciste


La aplicación no sólo facilita el envío de la solicitud, sino que también le ayuda a bloquear su calendario, eliminar citas y notificar automáticamente a los miembros del equipo sobre su próxima ausencia. Estos
Haga clic en bloquear
¡Son servicios inteligentes y útiles!

tu calendario


Seleccione AÑADIR

Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 9 de 27


Cancelar

Luego haga clic en
Hecho

Declaración de pago
Después de que haya decidido tomarse un tiempo libre, también es una buena idea comprobar sus finanzas antes de reservar un hotel.

Con un clic, verá su estado de cuenta de pago. Con todo en un solo lugar, la navegación es fácil e intuitiva. ¡Ve por el hotel de cinco estrellas!


Además de estos servicios, también puede mantener su información personal. Echemos un vistazo a lo fácil que es.



Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 10 de 27


Perfil
El perfil le brinda total transparencia sobre su trabajo, compensación y personal.

información... y la capacidad de actualizar su información personal.


La experiencia está diseñada para ser intuitiva para todos los empleados con el fin de proporcionar una forma rápida y sencilla de actualizar su información desde cualquier lugar donde se encuentren. Junto con la excelente experiencia del usuario, ha mejorado la calidad de los datos, lo cual es fundamental para generar informes precisos.



Desde tu perfil también podrás acceder directamente al organigrama. El organigrama te ofrece información completa.
Organigráma
transparencia en la organización con sus líneas jerárquicas sólidas y punteadas. La búsqueda

La funcionalidad le permite echar un vistazo a todos sus colegas.



Desde el perfil, también puedes cambiar cualquier cosa, desde tu dirección, información bancaria, datos de dependientes, hasta tus preferencias de desarrollo y trabajo geográfico. No es necesario enviar correos electrónicos, tickets ni llamadas telefónicas.



Ahora que hemos visto la experiencia de los empleados, veamos qué puede ver usted, como gerente, sobre su equipo.

Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 11 de 27


Equipo


La vista de equipo le brinda acceso directo a información y acciones sobre los miembros de su equipo y
Desplácese hacia abajo para
detalles sobre empleados.

Ubicación del equipo


Por ejemplo, por tus conversaciones con Freda (Nota: o equivalente regional) sabes que ella quiere mudarse a Berlín. Miremos a ver cómo está distribuido el equipo.



Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 12 de 27


Ya tienes miembros del equipo en Berlín, por lo que ella no estaría sola allí.



Ir a Freda (o

Aquí tiene transparencia sobre las actividades actuales de Freda (o su equivalente regional). Puedes asignar regional
actividades regulares y temas para su próxima reunión con nuestro equivalente de proceso de Rendimiento Continuo)
(CPM). Todas las actividades y comentarios se capturan con la aplicación SF.



Sabes que Freda (o su equivalente regional) quiere mudarse a Berlín y se le agregó y

documentó el tema antes de su última reunión utilizando nuestro Rendimiento Continuo

Plataforma de gestión (CPM). Esto le permite realizar un seguimiento de temas, actividades, logros y recopilar
Nota: Agregar tema
retroalimentación, que puede convertir un proceso anual de desempeño retrospectivo en uno hacia adelante.
mudarse a berlín
buscando…un proceso de valor agregado.

antes de la demostración

(CPM)
Desde aquí puede iniciar la transferencia como parte del autoservicio del Administrador.



Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 13 de 27


Haga clic en los tres
El cambio puede ser efectivo en cualquier momento (pasado, ahora o futuro). Para movimiento a otra ubicación puntos
y trabajo, su fecha futura del cambio (es decir, el primero del próximo mes).


Cambiar de trabajo y
Compensación

Información



Ingresar a la fecha

(por ejemplo, elegir primero

del próximo mes)


Freda (o su equivalente regional) ocupa un puesto vacante que tienes en tu equipo en Berlín. Ella trabajará como gerente de Seguridad y Salud.




Introduzca "Berlín

Salud” (o el

regional

equivalente para el

posición)

Nota la

la posición debería

aparecer. Cuando

allí, selecciónalo.


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 14 de 27



¡Eso es todo! No tienes que hacer nada más. Todos los atributos de la posición se completan automáticamente
la información del trabajo que Esto reduce drásticamente los esfuerzos de mantenimiento y hace incluso un
Desplácese hacia abajo para
El complejo proceso de recursos humanos es un servicio consumible que los gerentes pueden realizar ellos mismos.

Ubicación y trabajo
Título
¿Por qué? La solución reconoce que desea iniciar una transferencia sin un cambio de pago y

aplica automáticamente el proceso comercial prescrito para usted. En el pasado, había que conocer el proceso de recursos humanos y seleccionar el formulario correcto.




Su socio comercial de recursos humanos (en nuestro ejemplo, Tessa Walker o su equivalente regional) lo recogerá, lo revisará y lo finalizará, eliminando el papeleo o la administración engorrosa que a menudo
asociado con una transacción de recursos humanos.

Ahorrar

Una vez aprobada la solicitud, los datos cambiarán a partir de la fecha de vigencia que haya ingresado.



Esta experiencia móvil le permite automatizar sus procesos con autoservicio para cumplir con Show Workflow
requisitos actuales y futuros para la digitalización y traer un participante del entorno de servicio de consumibles
a su fuerza laboral.



Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 15 de 27


Entregar
En resumen… Esta experiencia móvil acerca los procesos de RR.HH. a su trabajo diario. Ya vio lo fácil que es mantener datos tanto como empleado como como gerente. Al simplificar el hecho de estar a cargo de sus propios datos, aumentará su calidad.



Ahora que ha visto lo fácil e intuitiva que es la experiencia para gerentes y empleados, veamos cómo un profesional de recursos humanos trabajará con SuccessFactors para mejorar los servicios de recursos humanos.



Pasos y consejos de demostración
Mensaje
Iniciar sesión como
A continuación se muestra un ejemplo de la página de inicio para un profesional de recursos humanos. Te brinda fácil acceso a todos los Twalker (o
sus tareas pendientes y su información son relevantes para usted, tanto como empleado/gerente como como
regional
Profesional de RRHH.

equivalente)


También puede compartir noticias de la empresa, como próximos eventos de recursos humanos o cambios de políticas, etc. Es el lugar perfecto para compartir información de forma rápida y sencilla.


Mostrar cómo moverse
azulejos y
personalizar casa
página
Haga clic en “Aprobar
Comencemos con lo que debes hacer ahora mismo. Verá junto a otras solicitudes el
Peticiones"
Transferencia Vanessa (o equivalente regional) recién iniciada. Repasemos los cambios propuestos.



Haga clic en Filtrar


Aquí puede ver el cambio solicitado en detalle y puede abrir información de respaldo que
Haga clic en "transferir
te ayuda en tu toma de decisiones.

sin cambio de sueldo”

para Freda (o
La transacción es correcta por lo que apruebas la solicitud.

regional


equivalente)


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 16 de 27


Además, se pueden filtrar todas las aprobaciones. Como profesional de recursos humanos que recibe múltiples solicitudes por día, esto le permite buscar flujos de trabajo y navegar o responder fácilmente.


preguntas.



Aprobar


Como ya has visto en la experiencia móvil, la aprobación cambia directamente los datos por lo que no se solicita más actividad. Que mejora el servicio de RRHH…para los empleados,
gerentes y usted!



Otro aspecto importante de tener todos los datos en una plataforma de recursos humanos común es la calidad del asesoramiento a los líderes empresariales. Hoy en día, solo el 52% de todos los líderes tienen datos y análisis a su alcance (informe Bersin by Deloitte Global Human Capital Trends 2016). Teniendo
La visibilidad de sus datos en cualquier momento es fundamental.

De regreso a casa
Una de las tareas de Tessa (o su equivalente regional) es monitorear la página de Indicadores clave de desempeño.
(KPI) y realizar consultas ad hoc.



En este ejemplo, se han logrado grandes avances en la reducción de las tarifas de terminación. esto se ve
Haga clic en enlace
bien pero aún quieres saber más; Entonces, profundiza un poco más.

Tarifa de terminación


Se ve el desarrollo anual y una medición del desempeño. Esto también se ve bien, ya que parece que no se pierden demasiados empleados de alto rendimiento.



Profundizando más, querrás saber el cálculo exacto de la tarifa de terminación. Este
Haga clic en Pregunta
es una de las 2000 métricas predefinidas con Workforce Analytics. Un subconjunto,
icono de marca
incluido este, viene con Employee Central.


*(Nota: WFA no está incluido con EC, pero siempre querrás mostrarlo durante la demostración). Descripción general de Employee Central (EC)
Solo para uso interno de SAP y socios
Página 17 de 27


Con estas capacidades de análisis de personas, obtendrá la información profunda y en tiempo real que necesita.
Analizar por
para influir de manera creíble en la toma de decisiones y mejorar los resultados comerciales. -- Datos en tu
Seleccionar todas las edades
¡puntas de los dedos!


También puede analizar los datos en diferentes dimensiones para comprender los impactos y los desafíos. Por ejemplo, con la distribución por edades, ves que tu nivel más alto
Las tarifas de terminación son para edades entre 30 y 39 años. Esto parece crítico ya que estos experimentados
Los empleados son la mayor fuente de nuevos líderes. Tessa (o equivalente regional)
Explore esto más adelante, pero puede estar relacionado con su última encuesta, que indicó problemas con el cuidado infantil y las opciones de trabajo flexible. Además del análisis del despido, Tessa (o su equivalente regional) también recibió una solicitud sobre la igualdad salarial en la organización.

Haga clic en la página de inicio
Quiere analizar si la empresa paga de manera equitativa y sin ningún sesgo de género. Normalmente
Investigar
Una pregunta así no podría responderse sin días de trabajo y recopilación manual de datos.

de diferentes fuentes.



Comenzar nuevo
Ahora puede analizar los datos... en función de varias métricas, dimensiones, tendencias y
investigación
pronóstico. La visualización permite comunicar claramente los hallazgos.



Usar campo de búsqueda
Una vez completado el análisis, se puede compartir simplemente descargando los resultados.

a…


Seleccionar promedio

métrica de relación de comparación


Seleccione género

dimensión


Seleccionar trabajo

función

dimensión
Para brindar estos conocimientos y aumentar la calidad del asesoramiento a los líderes empresariales, es importante tener todos los datos en una plataforma de recursos humanos común. Con Employee Central tienes

Todos los datos y procesos de recursos humanos en un solo lugar. Veamos ahora los datos subyacentes y los recursos humanos.
Haga clic en Analizar
procesos con más detalle.

Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 18 de 27


Escriba el organigrama en

Este es el organigrama que muestra las líneas jerárquicas actuales que ya hemos visto en la búsqueda de acciones.

en móvil. Es el punto de entrada "diario" tanto para sus gerentes como para sus empleados, y proporciona detalles sobre todas las relaciones laborales: empleados permanentes, trabajos contingentes, globales.


asignaciones. Todo dentro de una sola vista.



Buscar a Ralph

Brunnert (o

regional

equivalente)
Además de la relación gerente/empleado, la solución también le permite combinar toda la información organizacional a través de la gestión de puestos.



Sus datos de posición fluyen sin problemas a través de la solución, conduciendo datos y
Haga clic en la siguiente pestaña:
procesos en áreas como reclutamiento, sucesión y planificación de personal. en un rapido
Organigrama de posición
vista, se le presenta una instantánea de su plan de capacidad actual, lo que le permite
Búsqueda de personas:
permitirle tomar decisiones comerciales críticas basadas en posibles brechas de personal y total
Ralph Brunnert
utilización de la fuerza laboral.

(o regional

Cada vez que alguien es contratado o transferido a un puesto como Freda (o
equivalente)

equivalente), los atributos del puesto fluirán hacia los del trabajo del empleado,

asegurando una excelente calidad de los datos y eliminando el trabajo manual adicional.

Haga clic en su

posición y

jerarquía de posiciones

detalles
Finalmente, el alcance del control es visible, que es un KPI importante cuando hablamos de

organizaciones, y también indica la eficiencia de la estructura organizacional.



Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 19 de 27


Puede mirar su organización en el futuro y en el pasado. Si la fecha es
Haga clic en Hoy para
cambiado (el 1 del mes siguiente), el gráfico refleja la transferencia de Freda (o regional
muestra esa
equivalente).

la visualización puede

ser cambiado


(elige la fecha


que fue usado para


la posición y


cambio de ubicación

Ahora que hemos visto cómo la relación gerente/empleado y la Posición
previamente)

La gestión permite gestionar la fuerza laboral de manera eficiente, repasemos lo que es un

cómo se ve la relación entre unidades organizativas.



Haga clic en la empresa
Esta vista muestra las unidades organizativas en relación entre sí. Esto puede ser en una estructura de entidad legal
base o como vemos aquí en una vista funcional.

descripción general
Esta vista representa la estructura funcional de la empresa. De la misma manera se pueden visualizar estructuras legales, jerarquías de centros de costos, etc.

Haga clic en Negocios

Vista
Además, puede agregar un nuevo departamento directamente en esta vista, lo que le permite

Rediseñe su organización para impulsar la eficiencia organizacional.

Seleccionar Negocio

Unidad


La flexibilidad de Employee Central le permite diseñar su estructura organizativa de forma
Seleccionar productos
forma ágil. Las posibilidades combinan una estructura de mejores prácticas con Unidad de Negocio, División y Departamento, así como elementos organizativos configurables basados en sus necesidades específicas.
Abrir una división para
necesidades. Esto proporciona un fácil acceso a toda la información relevante sobre su conjunto organizacional.
y las personas y puestos asignados.

departamentos


Ahora que hemos visto la configuración organizacional subyacente para obtener una mejor visión de su
Vuelve a casa
organización, veamos más en los detalles de los datos de sus empleados y los procesos de recursos humanos.

Página

Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 20 de 27


Primero, el perfil del empleado donde puede ver todos los recursos humanos y el talento de un empleado.
paisaje.

Buscar a Freda
La información principal del perfil se puede dividir en diferentes secciones configurables, lo que hace que todos los perfiles (o regionales)
datos disponibles en un solo lugar.

equivalente) en
Dependiendo de sus permisos, los datos apropiados como personal, empleo, búsqueda de acciones de nómina y
y la información de beneficios se puede ver y cambiar.

abre a la gente
Al combinar datos básicos y de talento en un solo perfil, los gerentes, RRHH y empleados
perfil
ellos mismos tienen una visión holística de todos los datos relevantes para tomar las decisiones correctas.


Este concepto de ventanilla única permite un autoservicio eficiente e intuitivo, empoderando e involucrando a toda su fuerza laboral.



Además, una de nuestras principales ventajas de Employee Central es la localización entregada.


Ofrecemos esto para más de 89 países para información personal (formatos de dirección, IBAN, redes sociales).

Seguridad, etc.); pero, más importante aún, para información laboral. Cada cambio legal

llega a usted a través del Centro de actualización. Esto es fundamental para la integración con la nómina, así como para los informes legales, etc. Esto le permite mantener el rumbo sin ningún esfuerzo de su parte.



Además de esta oferta única de localización en la solución principal de recursos humanos, también ofrecemos auditoría
Haga clic en mostrar
capacidades alineadas con la normativa y normativa General de Protección de Datos
más en Personal
Reglamento (RGPD).

Información

Haga clic en el icono del reloj en
Aquí tiene la vista completa del historial laboral de su empleado en un formato fácil de leer con información laboral.
los cambios en el lado izquierdo y los detalles en el derecho, incluida la fecha y el creador del portal
El último cambio.


Como administrador de recursos humanos, puede actualizar fácilmente los datos aquí con todo el historial disponible para auditoría.

propósitos.

Cerrar la superposición

ventana
Además, se producirán ajustes retroactivos basados en cambios en el pasado y desencadenarán un nuevo cálculo de la nómina.



Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 21 de 27


Desplácese hasta
Aquí encontrará los componentes del salario bruto de Freda (o equivalente regional) que son
compensación
acordado contractualmente (o basado en una tarifa, si corresponde).

información
Los gráficos adicionales brindan una instantánea rápida de la estructura de compensación de un empleado que brinda información clave para la toma de decisiones para usted, Recursos Humanos y el gerente.



Haga clic en un específico
La información de nómina local se puede mantener desde la misma pantalla, independientemente del SAP
ejemplo regional
Solución de nómina que utilizas.

para tu pais
(Nota: tenga en cuenta que esto solo es válido para ECP o soluciones de nómina SAP HCM locales (por ejemplo, Alemania:
que son administrados por clientes o socios como ADP, NGA.)

seguro Social;

EE. UU.: Límites del IRS;
Esta es una gran ventaja para usted y RR.HH., ya que los datos son visibles y se mantienen desde un solo lugar.

Australia:


jubilación,

etc.)



Otra ventaja, especialmente cuando se trata de procesos transaccionales, es la capacidad
Iniciar sesión: Twalker;
para generar también documentos según los procesos.

Bienvenido1 (o
regional
equivalente)
Nota: manténgase en
mente tienes que
iniciar sesión cada vez
intentas abrir
este.

Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 22 de 27


Haga clic en Tomar acción
Aquí es donde se inician otros procesos y se pueden imprimir documentos. Estos son
mostrar la acción
actividades guiadas para usted como persona de recursos humanos y para gerentes que utilizan el autoservicio.

cual puede ser

tomado


Hemos visto los datos de los empleados, cómo se inician los procesos y cómo se realizan los cambios.
revisado. Ahora echemos un vistazo a cómo iniciar una nueva contratación en su solución de recursos humanos.

Contrataciones pendientes en
SuccessFactors, al ser una suite completa de recursos humanos, hace que contratar nuevos empleados sea eficiente y rápido.
a diferencia del dolor que a menudo se experimenta con los sistemas en silos. Aquí puede simplemente verificar la información recopilada durante el reclutamiento y la incorporación con la opción de agregar o
Haga clic en
anular según sea necesario.

Reclutamiento>Seleccionar


Inducción


Durante la incorporación, su empleado puede completar toda la documentación necesaria a partir de la cual
Contratar a Ingrid
su información verificada fluye a su registro de nuevas contrataciones, eliminando entradas duplicadas y Schmid (o
asegurando la integridad de los datos.

regional

equivalente)
Todos los procesos de RRHH proporcionan una experiencia para sus directivos y empleados que

aumenta el compromiso y le permite a usted, como RR.HH., optimizar su servicio.



Volver a

página de inicio para el

resumen total
Hoy vimos cómo SuccessFactors Employee Central proporciona un consumidor totalmente digital

experiencia de grado en recursos humanos. Al usar el móvil al principio, vimos que nuestra solución es

diseñado para ser una solución de autoservicio completa que impulsa su automatización y mejora su

servicio como Profesional de RRHH.



CLAUSURA
Al combinar todos los datos relevantes en una sola fuente mediante Employee Central, usted como
RR.HH. puede obtener información y análisis para desafiar las decisiones de las personas con sus líderes empresariales.


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 23 de 27


Nuestras mejores prácticas e innovaciones construyen la base para su transformación digital y le permitirán acercar a las personas al propósito de su empresa.

Opcional: Los siguientes pasos son opcionales según la oportunidad de su cliente potencial.
Pasos y consejos de demostración
Mensaje
LOCALIZACIÓN
Uno de los principales diferenciadores para nosotros es la localización. Además de implementar la solución,
Inicio>
Proporcionamos todos los cambios normativos y de cumplimiento en todo el mundo y en curso.
Empleado
Soporte de mantenimiento.

Mosaico de localización
¿Se imagina cuánto esfuerzo le supondría hacerse cargo de este mantenimiento sin utilizar una plataforma global?



Por el momento, ofrecemos localizaciones para más de 89 países de todo el mundo.

ver en este mapa mundial.


Además de las localizaciones generales, como monedas e identificaciones nacionales, también proporcionamos todos los campos.
Mapa general
solicitado por requisitos regulatorios o de cumplimiento.


Nuestro equipo de gerentes de productos de localización garantiza que estemos al día con los asuntos legales.

cambios en todo el mundo y entregamos esos cambios cuatro veces al año.



Nota: Tome un

Repasemos estas localizaciones.

país que encaja

a su cliente potencial

paisaje>Ir a

Localizaciones>Sho

w campos
Además de ofrecer una variedad de campos, proporcionamos informes localizados que ofrecemos dentro del repositorio de informes.



Con esta localización, podrá ejecutar su solución a escala global.


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 24 de 27


CENTRO DE ACTUALIZACIÓN
La aplicación se basa en una plataforma muy potente que se actualiza cuatro veces al año.

Volver a San Francisco
Esto garantiza que esté actualizado y pueda aprovechar las nuevas innovaciones que ofrecemos.

Buscar
Utilizar estas nuevas innovaciones no requiere alineación con su TI, definiendo un centro de actualización
proyectos o nuevas inversiones en hardware.

Puede utilizar nuestro Centro de actualizaciones para simplemente activar las nuevas innovaciones e implementarlas en su negocio. ¡Es así de fácil!


Aquí también encontrará información detallada sobre las próximas nuevas funciones.
ocurriendo cada tres meses. Si hay una nueva funcionalidad que le proporcionará

valor de la organización, puede realizar la actualización directamente desde aquí.

Nuestras actualizaciones se dividen en actualizaciones obligatorias y opcionales. También ofrecemos lo mejor
prácticas dentro del Centro de actualización, lo que le permite aprovechar el contenido prediseñado
de SuccessFactors. Este contenido se basa en los éxitos de los clientes.


Por ejemplo,... (Nota: ¡inserte una historia de cliente de EC!)
TIEMPO
Dentro de SuccessFactors, ofrecemos gestión centralizada de tiempo y asistencia de los empleados.

ir al tiempo
Esta es una parte nativa de Employee Central, por lo que no hay suscripción adicional.

sección en el perfil

Administrar hora>
El banco de trabajo de tiempo es su lugar central desde el cual monitorear y ajustar/corregir
Cuentas de tiempo

información sobre el tiempo del empleado según sea necesario.


Una de nuestras mayores fortalezas dentro de Employee Central Time Management es nuestra capacidad de ofrecer administración del tiempo de conformidad con las leyes y regulaciones locales. Ofrecemos un
plataforma con muchos componentes y lógica, como calendarios de vacaciones, reglas de acumulación,
reglas comerciales, etc. que puede utilizar para cumplir con los convenios colectivos de trabajo,
y leyes locales y federales.


Si el objetivo principal de la administración del tiempo de su cliente es pagar correctamente a las personas, EC
El tiempo es una gran solución. Maneja todas las ausencias de sus empleados y proporciona una correcta
Evaluación del tiempo para pagar correctamente a tus empleados.

Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 25 de 27


BENEFICIOS
Employee Central también viene con una solución nativa de gestión de beneficios. Lo global
Volver a la gente
El marco de beneficios es un sistema diseñado inteligentemente que es escalable, flexible y
perfil
garantiza la entrega y gestión de beneficios para cualquier organización en cualquier país.

Ir a Beneficios

Sección>

Tomemos, por ejemplo, las “asignaciones”, que son básicamente una cantidad fija de dinero disponible. Resumen de beneficios
a un empleado para pagar por algo. Puede que no cubra el coste total pero, aun así,
hay dinero reservado para cubrir este gasto. Por ejemplo, en Filipinas existe una “asignación para bolsas de arroz” o en algunos países de EMEA, hay una “asignación” reservada para
pagar por ropa de abrigo.


Nuestra solución de Beneficios Globales es lo suficientemente flexible como para permitirle implementar su beneficio.
tipos por país y permitir de manera efectiva a los empleados inscribirse, presentar un reclamo y obtener
reembolsado.


(Nota: cuando sea necesario para posicionar los beneficios en EE. UU., trabaje con su asesor de soluciones EC). CENTRO DE EXTENSIÓN
Cada empresa es única. Usando el Centro de Extensión, puede configurar formularios, negocios
Buscar
lógica y procesos de aprobación que satisfagan las necesidades específicas de su empresa.

Centro de Extensión
Hay un guión dedicado aquí.



A través de SAP Cloud Platform, puede aprovechar las aplicaciones desarrolladas en nuestro ecosistema. En nuestra tienda de aplicaciones, puede encontrar algunos excelentes ejemplos de ellos.

extensiones como la Red Alumni.


Para resumir:
• Las asociaciones le permiten ampliar las capacidades de nuestra solución según sea necesario para
satisfaga sus necesidades comerciales a través de integraciones productivas y aplicaciones desarrolladas por socios.

• Nuestros socios también nos apoyan a usted y a nosotros con una profunda experiencia en implementación y
aceleradores.


• Llamamos a esta capacidad colectiva el "Poder de SAP".

CIERRE 2

Hoy vimos cómo SuccessFactors Employee Central proporciona un consumidor totalmente digital
experiencia de grado en recursos humanos. Al usar el móvil al principio, vimos que nuestra solución es
diseñado para ser una solución de autoservicio completa que impulsa su automatización y mejora su servicio como profesional de recursos humanos.


Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 26 de 27


Al combinar todos los datos relevantes en una sola fuente mediante Employee Central, usted como
RR.HH. puede obtener información y análisis para desafiar las decisiones de las personas con sus líderes empresariales.


Nuestras mejores prácticas e innovaciones construyen la base para su transformación digital.


La localización garantiza que una solución escalable se ejecute a nivel global. Además, nuestro ecosistema y capacidades de extensión le brindan "El poder de SAP".


Todo esto en conjunto le permite conectar a su gente con el propósito de su empresa.

Temas adicionales que puede considerar agregar a su demostración de EC (a menudo, estos elementos se muestran y pueden complementar su demostración):
Temas de demostración de recursos humanos o administración de sistemas:
o Cambios masivos
o Permisos basados en roles (RBP)
o Servicios Inteligentes/Centro de Integración
o Centro de administración: flujo de trabajo/alertas de datos
o Configuración de Negocio, Nuevos Campos
Movilidad Global
Modelado de organización (Nakisha/Ingenui's)
Gestión Documental (Texto Abierto)
Mano de obra contingente

APÉNDICE:

Este script fue diseñado para admitir datos y configuraciones, por ejemplo 1708

Descripción general de Central de empleados (EC)
Solo para uso interno de SAP y socios
Página 27 de 27

"""
# Define the name mapping
name_mapping = {
    "vanessa":"vanitha","wagner":"kumar","freda":"rohini","hoch":"sharma","Amelie":"Priya","verrier":"patel","coline":"anjali","gage":"gupta","sandra":"meera","gray":"nair","liam":"leela","seaward":"selvan","mya":"maya","cooper":"dheeran","gordan":"karikalan","elliston":"cholan","tessa":"sunitha","walker":"desai","twalker":"prabudesai","brunnert":"kazhal","ralph":"menon"
}

# Replace names with localized versions
for name, localized_name in name_mapping.items():
    generated_text = generated_text.replace(name, localized_name)

# Print the post-processed text
print(generated_text)
# Out:
# Guión de demostración:
# Descripción general de la central de empleados
#
#
# Descripción general de Central de empleados (EC)
# Solo para uso interno de SAP y socios
# Página 1 de 27
#
#
# Objetivos:
# Para habilitar/familiarizarse con la demostración de EC.
#
# Para utilizarlo como punto de partida para planificar su demostración de EC.
#
# Consejos y trucos:
# La simplicidad es buena. Considere simplificar su perfil de personas y su función de autoservicio de administrador para que se elimine todo lo que no sea relevante para su historia.
#
# Refleje el modelo de prestación de recursos humanos de su cliente potencial. Si trabajan con un centro de servicios compartido y socios comerciales de recursos humanos, es posible que desee reflejarlo en las definiciones de su flujo de trabajo.
#
# Preparación:
# ...

# %%
# Define the test data
test_data = [
    {
        "language": "es",
        "country": "IND",
        "demo_script": """
        Demo Script:
Employee Central Overview


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 1 of 27


Objectives:
To enable/familiarize yourself with demoing EC.

To use as a starting point for planning your EC demo.

Tips and Tricks:
Simplicity is good. Consider simplifying your People Profile and manager self-service role so that everything that isn’t relevant for your story is removed.

Reflect your prospect’s HR delivery model. If they work with a shared service center and HR business partners, you may want to reflect it in your workflow definitions.

Preparation:
Workflows - Correct the transfer without pay change workflow to remove the manager role so they are not the approver for the transaction (This is fixed in the 2018 Summer Release).

o HOW:
Log in as sfadmin
Go to Admin Tools -> Manage Organization, Pay and Job Structures
In the first drop down, select Workflow
In the second drop down, select XFER
In the upper right corner, select Take Action -> Make correction
In the first step of the workflow, change the context field from Target to Source

Scroll down and Save
Make sure an absence approval for the manager you’re using is available.

o HOW:
Login as the employee you will be using
From the Home Page, select the Time Off tile
Select the time off bucket at the top that you want to use (e.g. vacation or your regional equivalent)
Select 1 or several days in the future for the leave request
Select Submit. You will be notified that the request has gone to the manager for approval.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 2 of 27


Delete the transfer of the employee you’re using if necessary.

o HOW:
Log in as the manager who created the original transfer request
Go to Manage Pending Requests via Action Search
Select the employee you are using and go to their Employee Profile
Locate the requested transfer under My Requests Waiting for Approval
Select the request
Scroll Down and click on Withdraw at the bottom. Select Yes when prompted.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 3 of 27


As an admin, verify the absence balances available for the employee and make sure they’re meaningful. Update as necessary.

o HOW:
Login as sfadmin
In Action Search, enter Administer Time
Enter the employee name who you are using
You will then be in the Time Workbench
Select Time Accounts
Note the time balances for the account you want to use
If there are not enough days:
Scroll down to Account Postings
Select Add Manual Adjustment
Enter in number of days
Select Save


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 4 of 27


Before you start the mobile demo just go to the steps beforehand to make sure you have cached the main steps. Loading times can be long.

The user mentioned in the script reflects the German user in the NGD2 master (Version 1708). You can use the global and other local users in the same way. Make sure that the data and processes behave like expected.

Germany: Vanessa Wagner, Freda Hoch
France: Amelie Verrier, Coline Gage
UK: Sandra Gray, Liam Seaward
US: Mya Cooper, Gordon Elliston


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 5 of 27


Introduction:

The digital revolution heavily impacts the way we work. Companies have to become increasingly global to remain successful or to find talent in other regions. In addition, there’s a shift in technology. Artificial Intelligence (AI) will help us deliver more automation and improve self-service concepts. For commerce, as well as for HR, people will start communicating with chat bots to get their questions answered on the spot because we’ve gotten used to technologies provided by LinkedIn, Facebook or Twitter to collaborate and communicate on the spot.


If the expectations of employees are different, business models are different, and technology is different, what kind of answer should technology provide us? At SuccessFactors, we think that technology should allow us to be in continuous dialogue with employees. To connect people to the purpose of your business. The usage should be continuous (mobile), engagement should be continuous, and it should allow people to be able to ask HR questions 24/7.


Technology also needs to be extensible because we know that every company works slightly different. While the majority of HR processes are the same, for those that aren’t, companies can have the competitive edge to plan their workforce smarter, train them better or connect them to the goals of the organization in a unique way.


Above all, solutions need to be intelligent. When all HR processes are harmonized on one platform, the amount of data you’re capturing is huge. Modern technology such as Machine Learning (ML) allows you to use this data to suggest better training for your employees or to hire better because technology allows you to remove unconscious bias from your processes.


This allows companies to react very quickly to market demands and pressures. This connects people to purpose.


What if you could have a fully digital consumer grade HR experience…one that provides you a single core platform based on best practices and built on a global HR
template? A platform where employees and managers can use their mobile devices to get real-time updates and allow speed to task. What if you can use this technology to connect your people to your purpose? With our Employee Central solution, you can implement a global HR template, and of course keeping in mind local variances, take advantage of the deep localization concept that SuccessFactors deliver. Our Local Product Managers ensure your application remains up-to-date so that you can ensure compliance with ever changing law and regulations. We deliver this deep localization in 90+ countries around the globe.


Today we’ll look at Employee Central from three perspectives: as an employee, a manager and a HR Administrator illustrating how you can connect your people to your purpose.


Let’s start as a manager and assume you’re sitting on a train on your way to work. The same way you use your email, Amazon, or other Apps, the SuccessFactors App has become a regular companion in your daily work. Let’s see how…


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 6 of 27


Steps & Demo Tips
Message
Mobile
As with any other application, you receive notifications from the SuccessFactors (SF) App. This tells you the to-do’s and makes it easy for you to stay on top of your HR related tasks.

Vanessa Wagner (or
regional equivalent)
Open SF App


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 7 of 27


The intuitive user experience has been developed in tight partnership between SAP and Apple to make use of the impact on a mobile experience at its best.

To-Do site
Also, research shows that adding mobile capabilities provides 49% of employees with a better user experience of HR functions (Sierra-Cedar 2014–2015 HR Systems Survey White Paper) and HR organizations who embrace mobile applications outperform organizations that don’t.



Here you find a pending leave request, performance reviews and a summary review of your performance calibration meeting that requires your attention.


The App also makes you aware of new functionality you should try out. This embedded

education allows your users to quickly become familiar with the possibilities.



Your first to-do is a leave request so letś see what an approval workflow looks like.



Open Leave

Request


Here’s all the information you need for the approval request. The type of leave, the requested amount, and information on other absences from your team members.


You can see the duration of the request as well as who else is on a leave from your team in that timeframe. In one place, you get all the relevant information on which to make your decision.


This is a great example of a user experience that is simple and engaging.



Approve the
request

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 8 of 27


Time Off from the
Another common example on simplifying HR processes is the absence request.

More Menu
With the App, it’s easy to review all your own planned absences, entitlements and your team absence calendar to help you schedule your time off.

Select the +


You can attach documents or photos to your request. As an example, sending sick notes to your manager.

Select Annual

Leave (or your
A one-stop shop right at your fingertips!

regional

equivalent)


Select the start

and end dates



Select Send


Select the request


you just did


The App makes it not only easy to submit the request, but also helps you to block your calendar, delete appointments and automatically notify team members of your upcoming absence. These
Click on block
are intelligent, helpful services!

your calendar


Select ADD


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 9 of 27


Cancel

Then click on
Done

Pay Statement
After you decided to take some time off, it’s also a good idea to check your financials before booking a hotel.

With one click, you see your pay statement. With everything in one place, navigation is easy and intuitive. Go for the five-star hotel!


Beside these services, you’re also able to maintain your personal information. Let’s take a look at how easy it is.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 10 of 27


Profile
The profile gives you full transparency about your job, compensation and personal

information…and the ability to update your personal information.


The experience is designed to be intuitive for all employees in order to provide a quick and easy way of updating their information from wherever they are. Along with the outstanding user experience, you have improved data quality which is critical for driving accurate reporting.



From your profile, you can also directly access the org chart. The org chart gives you full
OrgChart
transparency into the organization with its solid and dotted reporting lines. The search

functionality allows you to have a look at all your colleagues.



From the profile, you can also change anything from your address, bank information, dependent data, down to your development and geographic work preferences. No need for emails, tickets, or phone calls.



Now that we’ve seen the employee experience, let’s see what you as the manager can view about your team.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 11 of 27


Team


The team view gives you direct access to information and actions on your team members and
Scroll down to
employee details.

Team location


For example, from your discussions with Freda ( Note: or regional equivalent) you know she wants to move to Berlin. Let's look to see how the team is distributed.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 12 of 27


You already have team members in Berlin, so she wouldn’t be alone there.



Go to Freda (or

Here you have transparency on Freda’s (or regional equivalent) current activities. You can assign regional
regular activities and topics for your next meeting with our Continuous Performance process equivalent)
(CPM). All activities and comments are captured with the SF App.



You know Freda (or regional equivalent) wants to move to Berlin and she’s added and

documented the topic prior to your last meeting using our Continuous Performance

Management platform (CPM). This allows you to track topics, activities, achievements and collect
Note: Add Topic
feedback, which can turn an annual backward-looking performance process into a forward
move to Berlin
looking…a value-added process.

before demo

(CPM)
From here you can initiate the transfer as part of Manager self-service.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 13 of 27


Click the three
The change can be effective at any time (past, now or future). For movement to another location dots
and job, your future date the change (i.e. first of next month).


Change Job and
Compensation

Info



Enter as of date

(e.g. Choose first

of next month)


Freda (or regional equivalent) takes over a vacant position you have in your team in Berlin. She’s going to work as Health and Safety manager.




Enter “Berlin

Health” (or the

regional

equivalent for the

position)

Note: The

position should

appear. When

there, select it.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 14 of 27



That’s it! You don’t have to do anything else. All attributes of the position automatically populate
the job information which This dramatically reduces maintenance efforts and makes even a
Scroll down to
complex HR process a consumable service for managers to do themselves.

Location and Job
Title
Why? The solution recognizes you want to initiate a transfer without a Pay Change and

automatically applies the prescribed business process for you. In the past, you had to know the HR process and select the right form.




Your HR Business Partner (in our example Tessa Walker or regional equivalent) will pick it up, review it and finalize it eliminating the paperwork or cumbersome administration often
associated with an HR transaction.

Save

After the request is approved, the data will change as of the effective date you have entered.



This mobile experience allows you to automate your processes with self-service in order to meet Show Workflow
today's and future requirements for digitalization and bring a consumable service environment participant
to your workforce.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 15 of 27


Submit
To summarize…This mobile experience brings HR processes closer to your daily job. You saw how easy it is to maintain data as an employee as well as a manager. Making it simple to be in charge of your own data, you’ll increase the quality of it.



Now that you’ve seen how easy and intuitive the experience for managers and employees is, letś see how an HR Professional will work with SuccessFactors in order to improve HR services.



Steps & Demo Tips
Message
Login as
Here’s an example of the Home Page for a HR Professional. It gives you easy access to all Twalker (or
your to-dos and information is relevant for you, both as an employee/manager and as an
regional
HR Professional.

equivalent)


You could also share company news like upcoming HR events or policy changes, etc. It’s the perfect place to share information quickly and easily.


Show how to move
tiles and
personalize home
page
Click on “Approve
Let’s start with what you need to do right now. You see next to other requests the
Requests”
transfer Vanessa (or regional equivalent) just initiated. Let’s review the proposed changes.



Click on Filter


Here you see the requested change in detail and can open supporting information that
Click on “transfer
helps you in your decision making.

w/o pay change”

for Freda (or
The transaction is correct so you approve the request.

regional


equivalent)


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 16 of 27


Additionally, all the approvals can be filtered. As an HR Professional getting multiple requests per day, this allows you to search for workflows and easily navigate or answer


questions.



Approve


As you’ve already seen in the mobile experience, the approval directly changes the data so no further activity is requested. That improves the service of HR…for employees,
managers and you!



Another important aspect of having all data in one common HR platform is the quality of advice to your business leaders. Today only 52% of all leaders have data and analytics at their fingertips (Bersin by Deloitte Global Human Capital Trends 2016 report). Having
visibility into your data at a moment’s notice is critical.

Back to the home
One of Tessa’s (or regional equivalent) tasks is to monitor Key Performance Indicators page
(KPIs) and conduct ad-hoc queries.



In this example, great progress has been made in reducing termination rates. This looks
Click Link
good but you still want to know more; so, you dig a bit deeper.

Termination rate


You see the yearly development and a measurement against performance. This, too, looks good as you seem not to lose too many high performers.



Drilling down further, you want to know the exact calculation of the termination rate. This
Click Question
is one of the 2000 metrics that are predefined with Workforce Analytics. A subset,
mark icon
including this one, comes with Employee Central.


*( Note: WFA is not included with EC but you always want to show it during the demo.) Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 17 of 27


With these capabilities on people analytics, you gain the deep, real time insights you need
Analyze By
to credibly influence decision making and improve business results. -- Data at your
Select All Ages
fingertips!


You’re also able to analyze the data against different dimensions in order to understand impacts and challenges. For example, with age distribution, you see that your highest
termination rates are from the ages 30-39. This seems critical as these experienced
employees are the biggest source for new leaders. Tessa (or regional equivalent) will
explore this later, but this may be related to your latest survey, which indicated issues with child care and flexible working options. Besides the analysis of termination, Tessa (or regional equivalent) also received a request about equal pay in the organization.

Click Home Page
You want to analyse if the company pays equitably without any gender bias. Normally
Investigate
such a question couldn´t be answered without days of work and manually collecting data

from different sources.



Start new
Now you’re able to analyse the data…based on various metrics, dimensions, trends and
investigation
forecasting. The visualization allows to clearly communicate the findings.



Use search field
After the analysis is completed, the can be shared by simply downloading the results.

to…


Select Average

comp-ratio metric


Select gender

dimension


Select job

function

dimension
To deliver such insights and increase the quality of the advice to business leaders, it’s important to have all data in one common HR platform. With Employee Central you have

all data and HR processes in one place. Letś now look at the underlying data and HR
Click Analyze
processes in more detail.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 18 of 27


Type org chart in

This is the org chart that shows you the current reporting lines that we have already seen the action search

in mobile. It’s the “daily” entry point for your managers and employees, alike, providing detail on all employment relationships – permanent employees, contingent works, global


assignments. All within one view.



Search for Ralph

Brunnert (or

regional

equivalent)
Besides the manager/employee relationship, the solution also allows you to combine all organizational information through position management.



Your position data flows seamlessly throughout the solution, driving data and
Click on next tab:
processes in areas such as recruiting, succession and headcount planning. In one quick
Position org chart
view, you’re presented with a snapshot of your current capacity plan -- empowering
Search for people:
you to make critical business decisions based on possible headcount gaps and total
Ralph Brunnert
workforce utilization.

(or regional

Whenever someone is hired or transferred into a position like Freda (or regional
equivalent)

equivalent), the attributes of the position will flow to those of the employee’s job,

ensuring excellent data quality and eliminating extra manual work.

Click on his

position and

position hierarchy

details
Finally, span of control is visible which is an important KPI when we talk about

organizations, and also indicates the efficiency of the organizational set up.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 19 of 27


You can look at your organization in the future and the past. If the as of date is
Click on Today to
changed (1st of the next month) the chart reflects the transfer of Freda (or regional
show that
equivalent).

visualization can

be changed


(choose the date


that was used for


the position and


location change

Now that we’ve seen how the manager/employee relationship and Position
previously)

Management allows you to manage the workforce efficiently, letś review what an

organizational unit relationship looks like.



Click company
This view shows the org units in relation to each other. This can be either on a legal entity structure
basis or as we see here on a functional view.

overview
This view represents the functional structure of the company. Legal structures, cost center hierarchies, etc. can be visualized in the same way.

Click Business

View
Furthermore, you can add a new department directly on this view which allows you to

redesign your organization to drive organizational efficiency.

Select Business

Unit


The flexibility in Employee Central allows you to design your organizational structure in an
Select Products
agile way. The possibilities combine a best practice structure with Business Unit, Division and Department, as well as configurable organizational elements based on your specific
Open a division to
needs. This provides easy access to all relevant information about your organizational set show
up and the allocated people and positions.

departments


Now that we’ve seen the underlying organizational set up to gain better insight into your
Go back to home
organization, let’s look more into the details of your employee data and HR processes.

page

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 20 of 27


First, the employee profile where you can view an employee’s complete HR and talent
landscape.

Search for Freda
Core profile information can be split into different, configurable sections making all the (or regional
data available in one place.

equivalent) in
Depending on your permissions, the appropriate data like personal, employment, payroll action search and
and benefits information can be viewed and changed.

open the people
By combining core and talent data into one profile, managers, HR and employees
profile
themselves have a holistic view on all relevant data to make the right decisions.


This one stop shop concept allows for efficient and intuitive self-service, empowering and engaging your entire workforce.



In addition, one of our main advantages of Employee Central is the delivered localization.


We offer this for 89+ countries for personal information (address formats, IBAN, Social

Security, etc.); but, more importantly, for employment information. Every legal change

comes to you via the Upgrade Center. That’s critical for integration to payroll as well as for legal reporting, etc. This allows you to stay on track with no effort on your part.



Beside this unique offering of localization in the core HR solution, we also provide audit
Click on show
capabilities in alignment with the rules and regulations of General Data Protection
more in Personal
Regulation (GDPR).

Information

Click Clock Icon in
Here you have the full view of your employee’s job history in an easy to read format with job information
the changes on the left side and the details on the right, including date and originator of portal
the last change.


As the HR admin, you can easily update data here with all history available for audit

purposes.

Close the overlay

window
Additionally, retroactive adjustments will occur based on changes in the past and will trigger a payroll recalculation.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 21 of 27


Scroll to
Here you find the gross pay components of Freda (or regional equivalent) that are
compensation
contractually agreed upon (or based on a tariff, if applicable).

info
Additional graphs provide a quick snapshot of an employee’s compensation structure that provides key decision-making information for you/HR and the manager.



Click on a specific
Local payroll information can be maintained from the same screen, regardless of the SAP
regional example
Payroll solution you use.

for your country
( Note: Keep in mind that this is only valid for ECP or on-premise SAP HCM Payroll solutions (ex: Germany:
that are run by customers or partners like ADP, NGA.)

social insurance;

US: IRS Limits;
This is a great advantage for you/HR so data is visible and maintained from one place.

Australia:


Superannuation,

etc.)



Another advantage, especially when it comes to transactional processes, is the capability
Login: Twalker;
to also generate documents according to the processes.

Welcome1 (or
regional
equivalent)
Note: Keep in
mind you have to
log on every time
you try to open
this.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 22 of 27


Click Take action
Here’s where other processes are initiated and documents can be printed. These are
Show the action
guided activities for you as the HR person as well as managers using self -service.

which can be

taken


We’ve seen the employee data, how processes are initiated and how changes are
reviewed. Now let’s take a look at initiating a new hire into your HR solution.

Pending Hires in
SuccessFactors, being a full HR suite, makes it efficient and quick to hire a new employee Action Search
unlike the pain that is often experienced with siloed systems. Here you can simply verify the information collected during recruiting and onboarding with the option to add or
Click on
override as needed.

Recruiting>Select


Onboarding


During onboarding, your employee can complete all the necessary paperwork from which
Hire Ingrid
their verified information flows to their new hire record, eliminating duplicate entry and Schmid (or
ensuring data integrity.

regional

equivalent)
All HR processes provide an experience for your managers and employees which will

increase engagement and allows you as HR to optimize your service.



Go back to

homepage for the

overall summary
Today we saw how SuccessFactors Employee Central provides a fully digital consumer

grade HR experience. By using mobile at the beginning, we saw that our solution is

designed to be a full self-service solution which drives your automation and improves your

service as a HR Professional.



CLOSING
By combining all relevant data into one single source by using Employee Central, you as
HR can get insights and analytics to challenge people decisions with your business leaders.


Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 23 of 27


Our best practices and innovations build the base for your digital transformation and will allow you to put people to the purpose of your company.

Optional: The following steps are optional according to your prospect’s opportunity
Steps & Demo Tips
Message
LOCALIZATION
One of the main differentiators for us is localization. Aside of implementing the solution,
Home>
we provide all compliance and regulatory changes around the world and ongoing
Employee
maintenance support.

Localization Tile
Can you image how much effort it would be for you to take over this maintenance by not using a global platform?



At the moment, we provide localizations for 89+ countries around the world as you can

see on this world map.


Besides general localizations, like currencies and national idś, we also provide all fields
Overview Map
requested by regulatory or compliance requirements.


Our team of Localization Product Managers ensures that we are on track with legal

changes around the world and we deliver those changes four times a year.



Note: Take a

Letś review these localizations.

country that fits

to your prospect’s

landscape>Go to

Localizations>Sho

w fields
Along with offering a variety of fields, we provide localized reports that we offer within the report repository.



With this localization, you’re able to run your solution on a global scale.



Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 24 of 27


UPGRADE CENTER
The application is built on a very powerful platform which is updated four times a year.

Back to SF
This ensures you’re current and can take advantage of new innovations we deliver.

Search for
Utilizing these new innovations doesn’t require alignment with your IT, defining upgrade upgrade center
projects, or new hardware investments anymore.

You can use our Upgrade Center to simply switch on the new innovations and to roll it out to your business. It’s just that easy!


This is also where you’ll find detailed information about upcoming new functionality
occurring every three months. If there’s new functionality that will provide your

organization value, you can perform the upgrade directly from here.

Our upgrades are split into mandatory and optional upgrades. We also provide best
practices within the Upgrade Center, allowing you to take advantage of pre-built content
from SuccessFactors. This content is based on customer successes.


For example,… ( Note: insert an EC customer story!)
TIME
Within SuccessFactors, we offer Employee Central Time and Attendance Management.

Go to time
This is a native part of Employee Central, so there’s no additional subscription.

section in profile

Administer Time>
The time work bench is your central place from which to monitor and adjust/correct
Time Accounts

employee’s time information as needed.


One of our biggest strengths within Employee Central Time Management is our ability to offer time management in compliance with local laws and regulations. We offer a
platform with many components and logic, such as holiday calendars, accrual rules,
business rules, etc. which you can use to be compliant with collective labor agreements,
and local and federal laws.


If your customer’s main purpose for time administration is to correctly pay people, EC
Time is a great solution. It handles all your employee absences and provides a correct
time evaluation to correctly pay your employees.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 25 of 27


BENEFITS
Employee Central also comes with a native Benefits Management solution. The Global
Back to People
Benefits framework is an intelligently designed system that is scalable, flexible and
profile
ensures delivery and management of benefits for any organization in any country.

Go to Benefits

Section>

Take for example “allowances” which is basically a fixed amount of money that’s available Benefits overview
to an employee to pay for something. It may not cover the whole cost but nevertheless,
there’s money put aside to allow for this expense. For example, in the Philippines, there’s a “rice bag allowance” or in some countries in EMEA, there’s an “allowance” set aside to
pay for warm clothing.


Our Global Benefits solution is flexible enough to enable you to implement your benefit
types by country and effectively enable employees to enroll, file a claim and get
reimbursed.


( Note: When required to position US Benefits work with your EC Solution Advisor.) EXTENSION CENTER
Every company is unique. Using the Extension Center, you can configure forms, business
Search for
logic and approval processes that meet your company’s specific needs.

Extension Center
There is a dedicated script here.



Through the SAP Cloud Platform, you can take advantage of applications developed in our ecosystem. In our Application store, you can locate some great examples of those

extensions like the Alumni Network.


To summarize:
• The partnerships allow you to extend the capabilities of our solution as needed to
meet your business needs via productized integrations and partner developed apps.

• Our partners also support you and us with deep implementation expertise and
accelerators.


• We call this collective capability the ‘Power of SAP’.

CLOSING 2

Today we saw how SuccessFactors Employee Central provides a fully digital consumer
grade HR experience. By using mobile at the beginning, we saw that our solution is
designed to be a full self-service solution which drives your automation and improves your service as a HR Professional.

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 26 of 27


By combining all relevant data into one single source by using Employee Central, you as
HR can get insights and analytics to challenge people decisions with your business leaders.


Our best practices and innovations build the base for your digital transformation.


Localization ensures a scalable solution runs on a global level. Additionally, our Extension capabilities and ecosystem provides you with ‘The Power of SAP’.


All this together enables you to connect your people to the purpose of your company.

Additional topics to consider adding to your EC demo (Often these items are shown and can complement your demo) --
HR or system admin demo topics:
o Mass Changes
o Role Based Permissions (RBP)
o Intelligent Services/Integration Center
o Admin Center – Workflow/Data Alerts
o Business Configuration, New Fields
Global Mobility
Org Modelling (Nakisha/Ingenui’s)
Document Management (Open Text)
Contingent Labour

APPENDIX:

This Scripts was designed to support data and configurations for instance 1708

Employee Central (EC) Overview
for Internal SAP and Partner Use Only
Page 27 of 27



        """
    }
]

# Run the pipeline on the test data
localized_demo_scripts = []
def localize_demo_script(demo_script, language, country):
    # Implement localization pipeline
    localized_demo_script = "..."
    return localized_demo_script

for data in test_data:
    language = data["language"]
    country = data["country"]
    demo_script = data["demo_script"]
    
    # Use localization pipeline to generate a localized version of the demo script
    localized_demo_script = localize_demo_script(demo_script, language, country)
    
    # Store the result
    localized_demo_scripts.append(localized_demo_script)

# Evaluate the results
for demo_script, localized_demo_script in zip(test_data, localized_demo_scripts):
    # Check for errors, assess fluency and naturalness, verify requirements, etc.
    pass


# Print the test data
for data in test_data:
    print(f"Language: {data['language']}")
    print(f"Country: {data['country']}")
    print(f"Demo script: {data['demo_script']}")
    print()
# Out:
# Language: es
# Country: IND
# Demo script:
#         Demo Script:
# Employee Central Overview
#
#
# Employee Central (EC) Overview
# for Internal SAP and Partner Use Only
# Page 1 of 27
#
#
# Objectives:
# To enable/familiarize yourself with demoing EC.
#
# To use as a starting point for planning your EC demo.
#
# Tips and Tricks:
# Simplicity is good. Consider simplifying your People Profile and manager self-service role so that everything that isn’t relevant for your story is removed.
#
# Reflect your prospect’s HR delivery model. If they work with a shared service center and HR business partners, you may want to reflect it in your workflow definitions.
#
# Preparation:
# Workflows - Correct the transfer without pay change workflow to remove the manager role so they are not the approver for the transaction (This is fixed in the 2018 Summer Release).
#
# o HOW:
# Log in as sfadmin
# Go to Admin Tools -> Manage Organization, Pay and Job Structures
# ...

# %%
#Prepare the text for translation: Depending on the approach you choose, you may need to prepare the text for translation by an LLM or a machine translation system. This could involve splitting the text into smaller chunks or reformatting it in a specific way.
#use when it is needed
'''
from docx import Document

docx_path = 'C:/projects/Emplay assessment/demo-script-employee-central-overview.docx'

def extract_text_from_docx(docx_path):
    document = Document(docx_path)
    full_text = []
    for para in document.paragraphs:
        full_text.append(para.text)
    return '\n'.join(full_text)

from googletrans import Translator

def prepare_text_for_translation(text, chunk_size=50000):
    chunks = []
    while len(text) > chunk_size:
        idx = text.rfind(' ', 0, chunk_size)
        if idx == -1:
            idx = chunk_size
        chunk = text[:idx]
        chunks.append(chunk)
        text = text[idx:]
    chunks.append(text)
    return chunks

def translate_text(text, src_lang, dest_lang):
    translator = Translator()
    prepared_text = prepare_text_for_translation(text)
    translated_text = []
    for chunk in prepared_text:
        translation = translator.translate(chunk, src=src_lang, dest=dest_lang)
        translated_text.append(translation.text)
    return ' '.join(translated_text)

text = extract_text_from_docx(docx_path)
src_lang = 'en'
dest_lang = 'es'
translated_text = translate_text(text, src_lang, dest_lang)
print(translated_text)
'''

# %%
import streamlit as st
# Set the title of the app
st.title("Demo Script Localization")

# Add a file uploader widget
uploaded_file = st.file_uploader("Upload a demo script document")

# Add a dropdown menu for language and country selection
language = st.selectbox("Select language", ["Tamil","English", "French", "Spanish"])
country = st.selectbox("Select country", ["India","USA", "France", "Spain"])

# Add a button to generate the localized demo script
if st.button("Generate localized demo script"):
    # Implement your localization pipeline here
    localized_script = "This is where the localized demo script will be displayed"
    st.write(localized_script)

import openai_secret_manager

assert "openai" in openai_secret_manager.get_services()
secrets = openai_secret_manager.get_secret("openai")

openai.api_key = secrets["api_key"]


# Add a file uploader widget
uploaded_file = st.file_uploader("Upload a demo script document")

# Add a dropdown menu for language and country selection
language = st.selectbox("Select language", ["English", "French", "Spanish"])
country = st.selectbox("Select country", ["USA", "France", "Spain"])

# Add a button to generate the localized demo script
if st.button("Generate localized demo script"):
    # Read the uploaded file and pre-process the text
    demo_script = uploaded_file.getvalue().decode()
    # Implement your pre-processing steps here

    # Call the OpenAI API to generate the localized demo script
    response = openai.Completion.create(
        engine="davinci",
        prompt=demo_script,
        temperature=0.5,
        max_tokens=150,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )
    localized_script = response["choices"][0]["text"]

    # Display the localized demo script within the app
    st.write(localized_script)

from docx import Document
from docx.shared import Inches
import base64
from io import BytesIO

# Set the title of the app
st.title("My Streamlit App")

# Add a file uploader widget
uploaded_file = st.file_uploader("Upload a demo script document")

# Add a dropdown menu for language and country selection
language = st.selectbox("Select language", ["English", "French", "Spanish"])
country = st.selectbox("Select country", ["USA", "France", "Spain"])

# Add a button to generate the localized demo script
if st.button("Generate localized demo script"):
    # Implement your localization pipeline here
    localized_script = "This is where the localized demo script will be displayed"
    st.write(localized_script)

    # Create a DOCX document with the localized demo script
    doc = Document()
    doc.add_paragraph(localized_script)
    doc.add_page_break()

    # Save the DOCX document to a temporary file
    with BytesIO() as temp_file:
        doc.save(temp_file)
        temp_file.seek(0)
        b64 = base64.b64encode(temp_file.read()).decode()

    # Add a button to download the DOCX file
    href = f'<a href="data:application/vnd.openxmlformats-officedocument.wordprocessingml.document;base64,{b64}" download="localized_script.docx">Download DOCX</a>'
    st.markdown(href, unsafe_allow_html=True)
